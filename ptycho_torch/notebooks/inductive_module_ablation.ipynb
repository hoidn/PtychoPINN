# %% [markdown]
# # Introduction

# %% [markdown]
# This notebooks purpose is to do an frc comparison specifically only for models with certain inductive components ablated:
#
# 1. Supervised
# 2. Unsupervised no overlap
# 3. Unsupervised overlap, random coordinates
# 4. Unsupervised overlap, positional encoding

# %%
import importlib
import gc
import ptycho_torch.datagen
import ptycho_torch.reassembly
import ptycho_torch.helper
import ptycho_torch.dataloader
import ptycho_torch.patch_generator
importlib.reload(ptycho_torch.reassembly)
importlib.reload(ptycho_torch.helper)
importlib.reload(ptycho_torch.dataloader)
importlib.reload(ptycho_torch.patch_generator)
from ptycho_torch.reassembly import reconstruct_image, reassemble_multi_channel
from ptycho_torch.patch_generator import get_fixed_quadrant_neighbors_c4
import mlflow.pytorch
from mlflow import MlflowClient
import matplotlib.pyplot as plt
import torch
import numpy as np
from ptycho_torch.utils import load_all_configs_from_mlflow, update_existing_config
import os
from ptycho_torch.helper import center_crop
from ptycho_torch.train import print_auto_logged_info
from ptycho_torch.config_params import ModelConfig, TrainingConfig, DataConfig, InferenceConfig
from ptycho_torch.config_params import update_existing_config
from ptycho_torch.dataloader import TensorDictDataLoader, PtychoDataset, Collate
torch.cuda.empty_cache()

# %%
import ptycho_torch.eval.frc
import ptycho_torch.eval.eval_metrics
importlib.reload(ptycho_torch.eval.frc)
importlib.reload(ptycho_torch.eval.eval_metrics)

from ptycho_torch.eval.frc import frc_preprocess_images, _match_phases_least_squares
from ptycho_torch.eval.eval_metrics import FSC
from scipy.ndimage import fourier_shift
import glob

# %% [markdown]
# # Defining helper functions below

# %%
# Constant vars
relative_mlruns_path = '../../mlruns'
tracking_uri = f"file:{os.path.abspath(relative_mlruns_path)}"

# %%
def load_dataset(ptycho_dir, model_id, data_config_replace=None):
    """
    Loads dataset with configuration parameters linked to specific model ID.
    Args:
        ptycho_dir (str): Directory containing the ptychography data.
        model_id (str): Model ID to load the dataset configuration from.
        data_config_replace (dict, optional): Dictionary to replace specific data configuration parameters.
    """
    


    #Load configs
    data_config, model_config, training_config, inference_config = load_all_configs_from_mlflow(model_id,
                                                                                            tracking_uri)


    # Replace data config if avail
    if data_config_replace is not None:
        update_existing_config(data_config, data_config_replace)

    print('Creating dataset...')
    ptycho_dataset = PtychoDataset(ptycho_dir, model_config, data_config,
                                remake_map=True)

    return ptycho_dataset, data_config, model_config, training_config, inference_config

# %%
def load_model_and_reconstruct(model_id, ptycho_dataset,
                              data_config, model_config, training_config,
                              inference_config, inference_config_replace = None):
    """
    Loads the model and reconstructs the image from the dataset.
    Args:
        model_id (str): Model ID to load the model from.
        ptycho_dataset (PtychoDataset): Dataset containing the ptychography data.
        data_config (DataConfig): Data configuration parameters.
        model_config (ModelConfig): Model configuration parameters.
        training_config (TrainingConfig): Training configuration parameters.
        inference_config (InferenceConfig): Inference configuration parameters.
    """
    
    # Loading model
    mlflow.set_tracking_uri(tracking_uri)
    model_uri = f"runs:/{model_id}/model"
    loaded_model = mlflow.pytorch.load_model(model_uri)
    loaded_model.to('cuda')
    loaded_model.training = True

    # Reconstruct image
    print('Reconstructing image...')
    result, recon_dataset = reconstruct_image(loaded_model, ptycho_dataset,
                           training_config, data_config, model_config, inference_config)

    return result, recon_dataset

# %%
def get_target_and_prediction_images_and_window(result, recon_dataset, window_size=0):
    """
    Meant to be called on result of reconstruct_image which still resides on GPU.
    Gets target amplitude and phase images, as well as the prediction amplitude and phase images.
    Crops to specified window size if provided.
    Args:
        result (torch.Tensor): Result tensor from the reconstruction. Complex-valued
        recon_dataset (PtychoDataset): Dataset containing the ptychography data.
        window_size (int): Size of the window to crop the images to. If 0, no cropping is done. Will almost surely be greater than 0.
    Returns:
        np.ndarray: Numpy array of the result.
    """
    #Move result to CPU and remove channel dimension if needed
    im_cpu = result.to('cpu')
    if len(im_cpu.shape) == 3:
        im_cpu = im_cpu.squeeze()
    
    # Set to shorter variable for readability
    w = window_size

    # Object recon
    recon = im_cpu.detach().cpu().numpy().copy()[w:-w,w:-w]

    # Ground truth
    gt = recon_dataset.data_dict['objectGuess'][0].copy()#[w:-w,w:-w]
    gt = center_crop(gt, recon.shape[0])

    return gt, recon

# %%
def preprocess_and_calculate_frc(gt, recon):
    """
    Preprocesses the ground truth and reconstructed images, then calculates the Fourier Ring Correlation (FRC).
    Args:
        gt (np.ndarray): Ground truth image.
        recon (np.ndarray): Reconstructed image.
    Returns:
        tuple: FRC values and frequencies.
    """
    # Preprocess images
    aligned_gt, aligned_pred = frc_preprocess_images(gt, recon, image_prop='complex',verbose=True, align = False)

    # Calculate FRC
    FR_curve, x_FR, T_curve, x_T = FSC(aligned_gt, aligned_pred)

    # Calculate sum under curve until 1
    FR_AUC = np.sum(FR_curve[:np.where(x_FR - 0.5 > 0)[0][0]])/np.where(x_FR - 0.5 > 0)[0][0]

    return FR_curve, x_FR, FR_AUC

# %%
def save_frc_to_dict(FR_curve, x_FR, FR_AUC, frc_dict,
                     experiment_id, model_name, window_size):
    """
    Saves FRC values to dictionary with appropriate keys.
    """
    # In case frc_dict is not defaultdict
    if experiment_id not in frc_dict:
        frc_dict[experiment_id] = {}
    if model_name not in frc_dict[experiment_id]:
        frc_dict[experiment_id][model_name] = {}

    frc_dict[experiment_id][model_name]['x_FR'] = x_FR
    frc_dict[experiment_id][model_name]['FR_curve'] = FR_curve
    frc_dict[experiment_id][model_name]['FR_AUC'] = FR_AUC
    frc_dict[experiment_id][model_name]['window_size'] = window_size

    return frc_dict

# %%
def add_to_npz(filename, **new_arrays):
    """
    Adds new arrays to an existing .npz file or creates a new one if it doesn't exist.
    Args:
        filename (str): The name of the .npz file to which arrays will be added.
        **new_arrays: Arbitrary keyword arguments representing the new arrays to add.
    """
    try:
        # Load existing arrays
        existing = dict(np.load(filename))
        existing.update(new_arrays)
        np.savez(filename, **existing)
    except FileNotFoundError:
        # File doesn't exist yet, create it
        print("File not found")
        np.savez(filename, **new_arrays)

# %% [markdown]
# # Re-doing FRC analysis

# %%
file_list = [
            '../../data/pinn_velo_gold_tp_1_supervised',
            '../../data/pinn_velo_gold_tp_2_supervised',
            '../../data/pinn_velo_ic_1_supervised',
            '../../data/pinn_velo_ic_2_supervised',
            '../../data/pinn_velo_ncm_supervised',
            ]

model_dict = {
    'supervised': 'fb950794aaad49dba03ffee8cc6ea230', #Vanilla supervised with CBAM
    'unsupervised_cdi': 'b2a05bdc3acb4aa4adde50c00ae05f44', #Unsupervised model w/o overlaps
    'unsupervised_random': '5bd8835da18746f3a9a0636b9a718b4d', #Unsupervised model w/ overlaps and random placement
    'unsupervised_encoded': 'c21418cb510e44989198fa2ee8b15092' #Unsupervised model w/ overlaps and positional encoding (model in paper)
}

# Window size dict. All values should be 20 except for pinn_gold_tp_2, which is 40. Use only names of experiments without _syn or _exp suffixes
window_size_dict = {
    #Synthetic objects
    'pinn_velo_gold_tp_1_supervised': 20,
    'pinn_velo_gold_tp_2_supervised': 40,
    'pinn_velo_ic_1_supervised': 20,
    'pinn_velo_ic_2_supervised': 20,
    'pinn_velo_micro_lfp_supervised': 20,
    'pinn_velo_ncm_supervised': 20,
}

# %% [markdown]
# # Main workflow

# %%
from collections import defaultdict

save_path = '../../data/frc_results'
file_name = 'inductive_ablation.npz'

if not os.path.exists(save_path):
    os.makedirs(save_path)

if os.path.exists(save_path + file_name):
    print("Loading existing frc_results.npz")
    frc_dict = np.load(save_path + file_name, allow_pickle = True)['frc_dict'].item()
else:
    frc_dict = defaultdict(dict)

# %%
from collections import defaultdict

save_path = '../../data/frc_results'
file_name = 'inductive_ablation.npz'
frc_dict = defaultdict(dict)

# %%
#Just write out main analysis workflow here for FRC

for file in file_list:
    # Get experiment name
    exp_name = file.split('/')[-1]

    # Get model ID
    for model_name, model_id in model_dict.items():
        # Check if this iteration was already done
        if exp_name in frc_dict and model_name in frc_dict[exp_name]:
            print(f'Skipping {exp_name} with model {model_name}, already processed.')
            continue

        print(f'Processing {exp_name} with model {model_name}')
        # Check to see if need to replace data config
        if exp_name in ['pinn_velo_gold_tp_1_supervised', 'pinn_velo_ic_1_supervised']:
            data_config_replace = {"x_bounds": [0.07, 0.93],
                                   "y_bounds": [0.07, 0.93]}
        else:
            data_config_replace = {}

        data_config_replace['normalize'] = 'Batch'
        data_config_replace['probe_normalize'] = 'True'

        # Load dataset
        ptycho_dataset, data_config, model_config, training_config, inference_config = load_dataset(file, model_id,
                                                                                                  data_config_replace=data_config_replace)
        
        #Replacing inference config
        inference_config_replace = {'middle_trim': data_config.N//2,
                            'batch_size': 512,
                            'experiment_number': 0,
                            'pad_eval': True}

        update_existing_config(inference_config, inference_config_replace)
        
        
        print("Beginning reconstruction...")
        # Load model and reconstruct image
        result, recon_dataset = load_model_and_reconstruct(model_id, ptycho_dataset,
                                                        data_config, model_config,
                                                        training_config, inference_config)
        
        print("Recon complete. Beginning FRC calculation...")
        # Get target and prediction images
        gt, recon = get_target_and_prediction_images_and_window(result, recon_dataset,
                                                                window_size=window_size_dict[exp_name])

        # Preprocess and calculate FRC
        FR_curve, x_FR, FR_AUC = preprocess_and_calculate_frc(gt, recon)
        
        # Create entries if they don't exist
        if exp_name not in frc_dict:
            frc_dict[exp_name] = defaultdict(dict)
            if model_name not in frc_dict[exp_name]:
                frc_dict[exp_name][model_name] = defaultdict(dict)
        
        # Sanity check if frc_dict[exp_name][model_name] exists
        if model_name in frc_dict[exp_name]:
            print(f"frc_dict[{exp_name}][{model_name}] exists")
        
        frc_dict = save_frc_to_dict(FR_curve, x_FR, FR_AUC,frc_dict,
                                    exp_name, model_name,
                                    window_size=window_size_dict[exp_name])

        # Save intermediate results to .npz file
        print("Saving results to .npz file...")
        npz_filename = os.path.join(save_path, file_name)
        np.savez(npz_filename, frc_dict=frc_dict)
# Out:
# Skipping pinn_velo_gold_tp_1_supervised with model supervised, already processed.
# Skipping pinn_velo_gold_tp_1_supervised with model unsupervised_cdi, already processed.
# Skipping pinn_velo_gold_tp_1_supervised with model unsupervised_random, already processed.
# Skipping pinn_velo_gold_tp_1_supervised with model unsupervised_encoded, already processed.
# Skipping pinn_velo_gold_tp_2_supervised with model supervised, already processed.
# Skipping pinn_velo_gold_tp_2_supervised with model unsupervised_cdi, already processed.
# Skipping pinn_velo_gold_tp_2_supervised with model unsupervised_random, already processed.
# Processing pinn_velo_gold_tp_2_supervised with model unsupervised_encoded
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_gold_tp_2_supervised/supervised_pinn_gold_tp_2.npz, maximum x_range is (33.47206497192383, 566.5279541015625), yrange is (33.47703552246094, 630.52294921875)
# Creating memory mapped tensor dictionary...
# Memory map length: 5931
# Memory map creation time: 0.0016841888427734375
# Populating memory map for dataset 0
# Start - end = 5931
# grouping
# 4_quadrant
# Building KDTree for 7709 points...
# Processing 5931 potential central points...
# Finished quadrant neighbor processing. Found 5931 valid C=4 groups.
# Non-diffraction memory map write time: 0.6689403057098389
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0031]]]])
# Diffraction memory map write time: 0.20322966575622559
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 5931.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.2493441104888916 seconds
# Batch 1 completed in 0.24040937423706055 seconds
# Batch 2 completed in 0.23613691329956055 seconds
# Batch 3 completed in 0.23647522926330566 seconds
# Batch 4 completed in 0.23683404922485352 seconds
# Batch 5 completed in 0.2371232509613037 seconds
# Batch 6 completed in 0.23705410957336426 seconds
# Batch 7 completed in 0.23667144775390625 seconds
# Batch 8 completed in 0.23621177673339844 seconds
# Batch 9 completed in 0.23591327667236328 seconds
# Batch 10 completed in 0.23549461364746094 seconds
# Batch 11 completed in 0.13735294342041016 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=0.6324, ax_fit=0.0377, ay_fit=-0.1238
#   _match_phases: phase_ramp min=0.5516, max=0.7132, mean=0.6324
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ic_1_supervised with model supervised
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_1_supervised/supervised_pinn_ic_1.npz, maximum x_range is (33.129241943359375, 170.87075805664062), yrange is (33.0966911315918, 165.90330505371094)
# Creating memory mapped tensor dictionary...
# Memory map length: 779
# Memory map creation time: 0.0007121562957763672
# Populating memory map for dataset 0
# Start - end = 779
# Assigning labels...
# Non-diffraction memory map write time: 0.10353231430053711
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.01784515380859375
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 779.
# Beginning reconstruction...
# Reconstructing image...
# Padding Size: 60
# Batch 0 completed in 0.13042283058166504 seconds
# Padding Size: 60
# Batch 1 completed in 0.06968975067138672 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=-0.9508, ax_fit=-0.3020, ay_fit=-0.4606
#   _match_phases: phase_ramp min=-1.3320, max=-0.5695, mean=-0.9508
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# frc_dict[pinn_velo_ic_1_supervised][supervised] exists
# Saving results to .npz file...
# Processing pinn_velo_ic_1_supervised with model unsupervised_cdi
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_1_supervised/supervised_pinn_ic_1.npz, maximum x_range is (33.129241943359375, 170.87075805664062), yrange is (33.0966911315918, 165.90330505371094)
# Creating memory mapped tensor dictionary...
# Memory map length: 779
# Memory map creation time: 0.0006668567657470703
# Populating memory map for dataset 0
# Start - end = 779
# Non-diffraction memory map write time: 0.0012979507446289062
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.01586008071899414
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 779.
# Beginning reconstruction...
# Reconstructing image...
# Padding Size: 60
# Batch 0 completed in 0.13068151473999023 seconds
# Padding Size: 60
# Batch 1 completed in 0.06892824172973633 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=-1.2489, ax_fit=-0.1011, ay_fit=-0.2381
#   _match_phases: phase_ramp min=-1.4185, max=-1.0793, mean=-1.2489
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ic_1_supervised with model unsupervised_random
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_1_supervised/supervised_pinn_ic_1.npz, maximum x_range is (33.129241943359375, 170.87075805664062), yrange is (33.0966911315918, 165.90330505371094)
# Creating memory mapped tensor dictionary...
# Memory map length: 779
# Memory map creation time: 0.0006577968597412109
# Populating memory map for dataset 0
# Start - end = 779
# grouping
# <function get_neighbor_indices at 0x7f9db014dfc0>
# begin nn_indices
# nn_indices_bounded_shape (779, 7)
# Non-diffraction memory map write time: 0.008985042572021484
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.031218290328979492
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 779.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.1483159065246582 seconds
# Batch 1 completed in 0.07864141464233398 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=1.4201, ax_fit=-0.1400, ay_fit=-0.2735
#   _match_phases: phase_ramp min=1.2133, max=1.6268, mean=1.4201
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ic_1_supervised with model unsupervised_encoded
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_1_supervised/supervised_pinn_ic_1.npz, maximum x_range is (33.129241943359375, 170.87075805664062), yrange is (33.0966911315918, 165.90330505371094)
# Creating memory mapped tensor dictionary...
# Memory map length: 779
# Memory map creation time: 0.0006420612335205078
# Populating memory map for dataset 0
# Start - end = 779
# grouping
# 4_quadrant
# Building KDTree for 1143 points...
# Processing 779 potential central points...
# Finished quadrant neighbor processing. Found 779 valid C=4 groups.
# Non-diffraction memory map write time: 0.051912546157836914
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.022962570190429688
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 779.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.14938616752624512 seconds
# Batch 1 completed in 0.07799220085144043 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=0.6227, ax_fit=-0.1401, ay_fit=-0.2614
#   _match_phases: phase_ramp min=0.4219, max=0.8234, mean=0.6227
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ic_2_supervised with model supervised
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_2_supervised/supervised_pinn_ic_2.npz, maximum x_range is (33.003055572509766, 434.9969482421875), yrange is (33.472206115722656, 431.5278015136719)
# Creating memory mapped tensor dictionary...
# Memory map length: 7591
# Memory map creation time: 0.000659942626953125
# Populating memory map for dataset 0
# Start - end = 7591
# Assigning labels...
# Non-diffraction memory map write time: 0.9515738487243652
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.1614534854888916
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 7591.
# Beginning reconstruction...
# Reconstructing image...
# Padding Size: 181
# Batch 0 completed in 0.17502665519714355 seconds
# Padding Size: 181
# Batch 1 completed in 0.17063331604003906 seconds
# Padding Size: 181
# Batch 2 completed in 0.16730856895446777 seconds
# Padding Size: 181
# Batch 3 completed in 0.16615819931030273 seconds
# Padding Size: 181
# Batch 4 completed in 0.16623902320861816 seconds
# Padding Size: 181
# Batch 5 completed in 0.1664283275604248 seconds
# Padding Size: 181
# Batch 6 completed in 0.16659140586853027 seconds
# Padding Size: 181
# Batch 7 completed in 0.16669535636901855 seconds
# Padding Size: 181
# Batch 8 completed in 0.1664896011352539 seconds
# Padding Size: 181
# Batch 9 completed in 0.1664109230041504 seconds
# Padding Size: 181
# Batch 10 completed in 0.16625595092773438 seconds
# Padding Size: 181
# Batch 11 completed in 0.16616559028625488 seconds
# Padding Size: 181
# Batch 12 completed in 0.1660938262939453 seconds
# Padding Size: 181
# Batch 13 completed in 0.16580772399902344 seconds
# Padding Size: 181
# Batch 14 completed in 0.1381385326385498 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=-0.2170, ax_fit=-0.0190, ay_fit=0.0266
#   _match_phases: phase_ramp min=-0.2398, max=-0.1942, mean=-0.2170
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# frc_dict[pinn_velo_ic_2_supervised][supervised] exists
# Saving results to .npz file...
# Processing pinn_velo_ic_2_supervised with model unsupervised_cdi
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_2_supervised/supervised_pinn_ic_2.npz, maximum x_range is (33.003055572509766, 434.9969482421875), yrange is (33.472206115722656, 431.5278015136719)
# Creating memory mapped tensor dictionary...
# Memory map length: 7591
# Memory map creation time: 0.0007226467132568359
# Populating memory map for dataset 0
# Start - end = 7591
# Non-diffraction memory map write time: 0.0024785995483398438
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.14631962776184082
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 7591.
# Beginning reconstruction...
# Reconstructing image...
# Padding Size: 181
# Batch 0 completed in 0.1747124195098877 seconds
# Padding Size: 181
# Batch 1 completed in 0.17125916481018066 seconds
# Padding Size: 181
# Batch 2 completed in 0.16740155220031738 seconds
# Padding Size: 181
# Batch 3 completed in 0.16643381118774414 seconds
# Padding Size: 181
# Batch 4 completed in 0.16683554649353027 seconds
# Padding Size: 181
# Batch 5 completed in 0.16676640510559082 seconds
# Padding Size: 181
# Batch 6 completed in 0.1668550968170166 seconds
# Padding Size: 181
# Batch 7 completed in 0.16679596900939941 seconds
# Padding Size: 181
# Batch 8 completed in 0.16685056686401367 seconds
# Padding Size: 181
# Batch 9 completed in 0.16644024848937988 seconds
# Padding Size: 181
# Batch 10 completed in 0.16667890548706055 seconds
# Padding Size: 181
# Batch 11 completed in 0.16626763343811035 seconds
# Padding Size: 181
# Batch 12 completed in 0.1663680076599121 seconds
# Padding Size: 181
# Batch 13 completed in 0.16617965698242188 seconds
# Padding Size: 181
# Batch 14 completed in 0.13733291625976562 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=-0.5047, ax_fit=0.0107, ay_fit=0.0453
#   _match_phases: phase_ramp min=-0.5327, max=-0.4767, mean=-0.5047
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ic_2_supervised with model unsupervised_random
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_2_supervised/supervised_pinn_ic_2.npz, maximum x_range is (33.003055572509766, 434.9969482421875), yrange is (33.472206115722656, 431.5278015136719)
# Creating memory mapped tensor dictionary...
# Memory map length: 7591
# Memory map creation time: 0.0007138252258300781
# Populating memory map for dataset 0
# Start - end = 7591
# grouping
# <function get_neighbor_indices at 0x7f9db014dfc0>
# begin nn_indices
# nn_indices_bounded_shape (7591, 7)
# Non-diffraction memory map write time: 0.07805085182189941
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.23233842849731445
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 7591.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.1913774013519287 seconds
# Batch 1 completed in 0.18709063529968262 seconds
# Batch 2 completed in 0.18251967430114746 seconds
# Batch 3 completed in 0.18197965621948242 seconds
# Batch 4 completed in 0.18221473693847656 seconds
# Batch 5 completed in 0.1824018955230713 seconds
# Batch 6 completed in 0.1823728084564209 seconds
# Batch 7 completed in 0.18277335166931152 seconds
# Batch 8 completed in 0.182464599609375 seconds
# Batch 9 completed in 0.1824488639831543 seconds
# Batch 10 completed in 0.1829814910888672 seconds
# Batch 11 completed in 0.18197035789489746 seconds
# Batch 12 completed in 0.1817765235900879 seconds
# Batch 13 completed in 0.18208718299865723 seconds
# Batch 14 completed in 0.15158963203430176 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=2.1634, ax_fit=0.0016, ay_fit=0.0412
#   _match_phases: phase_ramp min=2.1420, max=2.1848, mean=2.1634
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ic_2_supervised with model unsupervised_encoded
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ic_2_supervised/supervised_pinn_ic_2.npz, maximum x_range is (33.003055572509766, 434.9969482421875), yrange is (33.472206115722656, 431.5278015136719)
# Creating memory mapped tensor dictionary...
# Memory map length: 7591
# Memory map creation time: 0.0007224082946777344
# Populating memory map for dataset 0
# Start - end = 7591
# grouping
# 4_quadrant
# Building KDTree for 9436 points...
# Processing 7591 potential central points...
# Finished quadrant neighbor processing. Found 7591 valid C=4 groups.
# Non-diffraction memory map write time: 0.5055005550384521
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0032]]]])
# Diffraction memory map write time: 0.2180616855621338
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 7591.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.19648098945617676 seconds
# Batch 1 completed in 0.1931781768798828 seconds
# Batch 2 completed in 0.18765568733215332 seconds
# Batch 3 completed in 0.18631768226623535 seconds
# Batch 4 completed in 0.18624138832092285 seconds
# Batch 5 completed in 0.18634033203125 seconds
# Batch 6 completed in 0.18645429611206055 seconds
# Batch 7 completed in 0.18671536445617676 seconds
# Batch 8 completed in 0.18648910522460938 seconds
# Batch 9 completed in 0.18639779090881348 seconds
# Batch 10 completed in 0.18644475936889648 seconds
# Batch 11 completed in 0.18604469299316406 seconds
# Batch 12 completed in 0.18595480918884277 seconds
# Batch 13 completed in 0.18581557273864746 seconds
# Batch 14 completed in 0.15346264839172363 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=1.3683, ax_fit=-0.0435, ay_fit=0.0195
#   _match_phases: phase_ramp min=1.3368, max=1.3998, mean=1.3683
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ncm_supervised with model supervised
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ncm_supervised/supervised_pinn_ncm.npz, maximum x_range is (33.11264419555664, 240.88735961914062), yrange is (33.431095123291016, 232.56890869140625)
# Creating memory mapped tensor dictionary...
# Memory map length: 1902
# Memory map creation time: 0.0007586479187011719
# Populating memory map for dataset 0
# Start - end = 1902
# Assigning labels...
# Non-diffraction memory map write time: 0.260317325592041
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0012]]]])
# Diffraction memory map write time: 0.050965070724487305
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 1902.
# Beginning reconstruction...
# Reconstructing image...
# Padding Size: 94
# Batch 0 completed in 0.13933205604553223 seconds
# Padding Size: 94
# Batch 1 completed in 0.13861799240112305 seconds
# Padding Size: 94
# Batch 2 completed in 0.13627314567565918 seconds
# Padding Size: 94
# Batch 3 completed in 0.09822702407836914 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=-0.0660, ax_fit=0.3793, ay_fit=-0.0751
#   _match_phases: phase_ramp min=-0.2932, max=0.1613, mean=-0.0660
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# frc_dict[pinn_velo_ncm_supervised][supervised] exists
# Saving results to .npz file...
# Processing pinn_velo_ncm_supervised with model unsupervised_cdi
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ncm_supervised/supervised_pinn_ncm.npz, maximum x_range is (33.11264419555664, 240.88735961914062), yrange is (33.431095123291016, 232.56890869140625)
# Creating memory mapped tensor dictionary...
# Memory map length: 1902
# Memory map creation time: 0.0006644725799560547
# Populating memory map for dataset 0
# Start - end = 1902
# Non-diffraction memory map write time: 0.0015680789947509766
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0012]]]])
# Diffraction memory map write time: 0.03722023963928223
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 1902.
# Beginning reconstruction...
# Reconstructing image...
# Padding Size: 94
# Batch 0 completed in 0.13907074928283691 seconds
# Padding Size: 94
# Batch 1 completed in 0.13778996467590332 seconds
# Padding Size: 94
# Batch 2 completed in 0.1360797882080078 seconds
# Padding Size: 94
# Batch 3 completed in 0.09546709060668945 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=-0.4809, ax_fit=0.8345, ay_fit=0.5385
#   _match_phases: phase_ramp min=-1.1674, max=0.2056, mean=-0.4809
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ncm_supervised with model unsupervised_random
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ncm_supervised/supervised_pinn_ncm.npz, maximum x_range is (33.11264419555664, 240.88735961914062), yrange is (33.431095123291016, 232.56890869140625)
# Creating memory mapped tensor dictionary...
# Memory map length: 1902
# Memory map creation time: 0.0006530284881591797
# Populating memory map for dataset 0
# Start - end = 1902
# grouping
# <function get_neighbor_indices at 0x7f9db014dfc0>
# begin nn_indices
# nn_indices_bounded_shape (1902, 7)
# Non-diffraction memory map write time: 0.019338130950927734
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0012]]]])
# Diffraction memory map write time: 0.05212831497192383
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 1902.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.1564016342163086 seconds
# Batch 1 completed in 0.1558856964111328 seconds
# Batch 2 completed in 0.1529712677001953 seconds
# Batch 3 completed in 0.11088061332702637 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=1.1846, ax_fit=-0.5300, ay_fit=-0.7000
#   _match_phases: phase_ramp min=0.5696, max=1.7996, mean=1.1846
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...
# Processing pinn_velo_ncm_supervised with model unsupervised_encoded
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_ncm_supervised/supervised_pinn_ncm.npz, maximum x_range is (33.11264419555664, 240.88735961914062), yrange is (33.431095123291016, 232.56890869140625)
# Creating memory mapped tensor dictionary...
# Memory map length: 1902
# Memory map creation time: 0.0006608963012695312
# Populating memory map for dataset 0
# Start - end = 1902
# grouping
# 4_quadrant
# Building KDTree for 2466 points...
# Processing 1902 potential central points...
# Finished quadrant neighbor processing. Found 1902 valid C=4 groups.
# Non-diffraction memory map write time: 0.12536144256591797
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0012]]]])
# Diffraction memory map write time: 0.05687308311462402
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 1902.
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.15986251831054688 seconds
# Batch 1 completed in 0.15830469131469727 seconds
# Batch 2 completed in 0.1578371524810791 seconds
# Batch 3 completed in 0.11071348190307617 seconds
# Recon complete. Beginning FRC calculation...
# Starting FRC pre-processing...
# Step 3: Final phase matching of img1 to img2.
#   _match_phases: a0=0.3814, ax_fit=-0.3212, ay_fit=-0.3318
#   _match_phases: phase_ramp min=0.0549, max=0.7079, mean=0.3814
# Step 4: Applying soft-edge taper (20 px).
# FRC pre-processing complete.
# performed by index method
# performed by index method
# performed by index method
# Saving results to .npz file...

# %%
list(frc_dict['pinn_velo_gold_tp_1_supervised'].keys())
# Out:
# ['supervised',
#  'unsupervised_cdi',
#  'unsupervised_random',
#  'unsupervised_encoded']

# %% [markdown]
# # Looking at results

# %%
frc_path = '../../data/frc_results/inductive_ablation.npz'
# Load the frc_dict from the npz file
frc_dict = np.load(frc_path, allow_pickle=True)['frc_dict'].item()

# %% [markdown]
# ## Helper Functions

# %%
# For a given key in frc_dict and experiment name, assign x_FR, FR_curve and FR_AUC to numpy arrays. Concatenate them along the first axis.

def get_frc_arrays(frc_dict, exp_name):
    """
    Gets the FRC arrays for a given experiment name and model name from the frc_dict.
    Args:
        frc_dict (dict): Dictionary containing FRC results.
        exp_name (str): Experiment name.
        model_name (str): Model name.
    Returns:
        tuple: x_FR, FR_curve, FR_AUC as numpy arrays.
    """

    x_FR = []
    FR_curve = []
    FR_AUC = []
    model_list = list(frc_dict[exp_name].keys())  # Get the first model name for the experiment

    for model_name in frc_dict[exp_name].keys():
        x_FR.append(frc_dict[exp_name][model_name]['x_FR'])
        FR_curve.append(frc_dict[exp_name][model_name]['FR_curve'])
        FR_AUC.append(frc_dict[exp_name][model_name]['FR_AUC'])

    return x_FR, FR_curve, FR_AUC, model_list

# %%
def calculate_threshold_frc(x_FR):
    """
    Calculates the threshold FRC curve based on the x_FR array.
    Args:
        x_FR (list): List of x_FR arrays for different models.
    Returns:
        x_T, T_curve (tuple): Threshold FRC values and corresponding frequencies.
    """
    # Calculate threshold FRC curve (taken from eval_metrics.py)
    SNRt = 0.1
    eps = np.finfo(float).eps
    r = np.arange(1+x_FR.shape[0]/2)
    n = 2*np.pi*r
    n[0] = 1
    t1 = np.divide(np.ones(np.shape(n)),n+eps)
    t2 = SNRt + 2*np.sqrt(SNRt)*t1 + np.divide(np.ones(np.shape(n)),np.sqrt(n))
    t3 = SNRt + 2*np.sqrt(SNRt)*t1 + 1
    T_curve = np.divide(t2,t3)
    x_T = r/(x_FR.shape[0]/2)

    return x_T, T_curve

# %%
# Plot FRC curves for a given experiment

def plot_frc_curves(frc_dict, exp_name, experiment_type = 'exp'):
    """
    Plots the FRC curves for a given experiment name.
    Args:
        frc_dict (dict): Dictionary containing FRC results.
        exp_name (str): Experiment name.
    """

    x_FR, FR_curve, FR_AUC, model_name = get_frc_arrays(frc_dict, exp_name)

    # Generate figure
    plt.figure(figsize=(10, 6))

    for i, model in enumerate(model_name):
        x_FR_i, FR_curve_i, FR_AUC_i = x_FR[i], FR_curve[i], FR_AUC[i]

        # Check if model is in experiment type
        plot_name = model#'_'.join(model.split('_')[1:])
        plt.plot(x_FR_i, FR_curve_i, label=f'{plot_name}, AUC = {FR_AUC_i:.2f}')

        # Calculate and plot t once only
        if i == len(model_name) - 1:
            #Calculate the t curve
            x_T, T_curve = calculate_threshold_frc(x_FR_i)
            plt.plot(x_T, T_curve, label='SNR = 0.1', linestyle='--', color='red')
            
    plt.xlabel('Spatial Frequency (1/nm)')
    plt.ylabel('FRC')
    plt.xlim(0, 0.6)
    plt.ylim(0, 1)
    plt.title(f'FRC Curve for {exp_name}, {experiment_type}')
    plt.legend()
    plt.grid()
    plt.show()

# %%
exp_names = [
    #Synthetic objects
    'pinn_velo_gold_tp_1_supervised',
    'pinn_velo_gold_tp_2_supervised',
    'pinn_velo_ic_1_supervised',
    'pinn_velo_ic_2_supervised',
    'pinn_velo_ncm_supervised',
]

plot_frc_curves(frc_dict, exp_names[3], 'syn')

# %% [markdown]
# # Reconstruction plot

# %% [markdown]
# ## Helper functions

# %%
## Quick and dirty reconstruction plotting

def generate_gt_and_recon(file, model_name, model_dict):
    
    model_id = model_dict[model_name]

    exp_name = file.split('/')[-1]

    data_config_replace = {}

    data_config_replace['normalize'] = 'Batch'
    data_config_replace['probe_normalize'] = 'False'
    data_config_replace['n_subsample'] = 1
    data_config_replace["x_bounds"] = [0.05, 0.95]
    data_config_replace["y_bounds"] = [0.05, 0.95] 

    # Check to see if need to replace data config
    if exp_name in ['pinn_velo_gold_tp_1_supervised', 'pinn_velo_ic_1_supervised']:
        data_config_replace["x_bounds"] = [0.07, 0.93]
        data_config_replace["y_bounds"] = [0.07, 0.93]
    
    ptycho_dataset, data_config, model_config, training_config, inference_config = load_dataset(file, model_id,
                                                                                                  data_config_replace=data_config_replace)
    print("dset length", len(ptycho_dataset))
    #Replacing inference config
    inference_config_replace = {'middle_trim': data_config.N//2,
                        'batch_size': 512,
                        'experiment_number': 0,
                        'pad_eval': True}

    update_existing_config(inference_config, inference_config_replace)
        
        
    print("Beginning reconstruction...")
    # Load model and reconstruct image
    result, recon_dataset = load_model_and_reconstruct(model_id, ptycho_dataset,
                                                    data_config, model_config,
                                                    training_config, inference_config)
    
    print("final shape:", result.shape)
    
    # Get target and prediction images
    print("Windowing image...")
    gt, recon = get_target_and_prediction_images_and_window(result, recon_dataset,
                                                                window_size=1)
    
    return gt, recon

# %%
def plot_amp_and_phase(obj_amp, obj_phase, gt_amp, gt_phase):
    fig, axs = plt.subplots(2,2, figsize=(5,5))
    
    # obj_im[obj_im<-2] = 3
    #Object amp
    obj_plot = axs[0,0].imshow(obj_amp, cmap = 'gray')
    plt.colorbar(obj_plot, ax = axs[0,0])
    axs[0,0].set_title('Object Amplitude')
    axs[0,0].axis('off')

    #Object Phase
    phase_plot = axs[0,1].imshow(obj_phase, cmap = 'gray')#, vmin=-1, vmax=1)
    plt.colorbar(phase_plot, ax = axs[0,1])
    axs[0,1].set_title('Object Phase')
    axs[0,1].axis('off')

    #Ground turth amp
    gtamp_plot = axs[1,0].imshow(gt_amp, cmap = 'gray')
    plt.colorbar(gtamp_plot, ax = axs[1,0])
    axs[1,0].set_title('Ground Truth Amplitude')
    axs[1,0].axis('off')

    #ground truth phase
    gtphase_plot = axs[1,1].imshow(gt_phase, cmap = 'gray')
    plt.colorbar(gtphase_plot, ax = axs[1,1])
    axs[1,1].set_title('Ground Truth Phase')
    axs[1,1].axis('off')

# %%
def plot_single_amp_and_phase(obj_amp, obj_phase, title = 'Object'):
    """
    Plots a single amplitude and phase image.
    Args:
        obj_amp (np.ndarray): Object amplitude image.
        obj_phase (np.ndarray): Object phase image.
        title (str): Title for the plot.
    """
    fig, axs = plt.subplots(2, 1, figsize=(5, 5))
    
    # Object amp
    amp_plot = axs[0].imshow(obj_amp, cmap='gray')
    plt.colorbar(amp_plot, ax = axs[0], pad = 0.02)
    #Move colorbar directly next to plot
    axs[0].set_title('Amplitude')
    axs[0].axis('off')

    # Object Phase
    phase_plot = axs[1].imshow(obj_phase, cmap='gray')
    plt.colorbar(phase_plot, ax = axs[1], pad = 0.02)
    axs[1].set_title('Phase')
    axs[1].axis('off')

    plt.suptitle(title, fontsize = 14, fontweight='bold', x = 0.6)
    # plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reconstruction and showing reconstruction results

# %%
exp_names = [
    #Synthetic objects
    'pinn_velo_gold_tp_1_supervised',
    'pinn_velo_gold_tp_2_supervised',
    'pinn_velo_ic_1_supervised',
    'pinn_velo_ic_2_supervised',
    'pinn_velo_ncm_supervised',
]

model_i = 3
model_names = ['supervised', 'unsupervised_cdi', 'unsupervised_random', 'unsupervised_encoded']
model_name = model_names[model_i]

gt, recon = generate_gt_and_recon('../../data/pinn_velo_gold_tp_2', model_name, model_dict)
# Out:
# Creating dataset...
# Calculating dataset length with coordinate bounds...
# For file ../../data/pinn_velo_gold_tp_2/nxs_data_gold_tp_2_64_train.npz, maximum x_range is (33.47206497192383, 566.5279541015625), yrange is (33.47703552246094, 630.52294921875)
# Creating memory mapped tensor dictionary...
# Memory map length: 5931
# Memory map creation time: 0.0013530254364013672
# Populating memory map for dataset 0
# Start - end = 5931
# grouping
# 4_quadrant
# Building KDTree for 7709 points...
# Processing 5931 potential central points...
# Finished quadrant neighbor processing. Found 5931 valid C=4 groups.
# Non-diffraction memory map write time: 0.7221708297729492
# Getting normalization coefficients...
# Batch rms factor is tensor([[[[0.0031]]]])
# Diffraction memory map write time: 0.2505002021789551
# [PtychoDataset Rank 0] Initialization successful. Dataset length: 5931.
# dset length 5931
# Beginning reconstruction...
# Reconstructing image...
# Batch 0 completed in 0.2506842613220215 seconds
# Batch 1 completed in 0.24040818214416504 seconds
# Batch 2 completed in 0.23677635192871094 seconds
# Batch 3 completed in 0.23743462562561035 seconds
# Batch 4 completed in 0.23805594444274902 seconds
# Batch 5 completed in 0.23877429962158203 seconds
# Batch 6 completed in 0.23816275596618652 seconds
# Batch 7 completed in 0.23765277862548828 seconds
# Batch 8 completed in 0.2372734546661377 seconds
# Batch 9 completed in 0.23686623573303223 seconds
# Batch 10 completed in 0.23651814460754395 seconds
# Batch 11 completed in 0.13829660415649414 seconds
# final shape: torch.Size([1, 576, 576])
# Windowing image...

# %%
target_size = 480

recon = center_crop(recon, target_size)
gt = center_crop(gt, target_size)

obj_amp, obj_phase = np.abs(recon), np.angle(recon)
# obj_phase[obj_phase > 0] = -np.pic
gt_amp, gt_phase = np.abs(gt), np.angle(gt)
plot_single_amp_and_phase(obj_amp, obj_phase, title = '')
# plot_single_amp_and_phase(gt_amp, gt_phase, title = 'Ground Truth')

# %%
obj_amp, obj_phase = np.abs(recon), np.angle(recon)
# obj_phase[obj_phase > 0] = -np.pic
gt_amp, gt_phase = np.abs(gt), np.angle(gt)
# plot_single_amp_and_phase(obj_amp, obj_phase, title = model_name)
plot_single_amp_and_phase(gt_amp, gt_phase, title = '')
