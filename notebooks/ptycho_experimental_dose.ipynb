# %%
from importlib import reload
import matplotlib.pyplot as plt

def init():
    from ptycho import params as p
    p.cfg['size'] = 392
    p.cfg['positions.provided'] = False
    p.cfg['data_source'] = 'experimental'
    p.cfg['nepochs'] = 60
    p.cfg['set_phi'] = True
    p.cfg['nphotons'] = 1e9

    p.cfg['offset'] = 4
    p.cfg['max_position_jitter'] = 3
    p.cfg['output_prefix'] = 'tmp'

    p.cfg['gridsize'] = 2
    p.cfg['n_filters_scale'] = 2
    p.cfg['object.big'] = True
    p.cfg['intensity_scale.trainable'] = True
    p.cfg['probe.trainable'] = False
    
    p.cfg['outer_offset_train'] = 8
    p.cfg['outer_offset_test'] = 20
    p.cfg['nimgs_train'] = 1
    p.cfg['nimgs_test'] = 1
    
init()

from ptycho.evaluation import save_metrics
from ptycho.evaluation import trim
from ptycho import tf_helper as hh
from ptycho import probe
# Out:
# 2024-11-21 19:21:37.731574: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-21 19:21:37.731604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-21 19:21:37.732843: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 19:21:37.738313: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-21 19:21:38.345693: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-11-21 19:21:39.042168: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.075751: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.075995: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2 items had no tests:
#     __main__
#     __main__.init
# 0 tests in 2 items.
# 0 passed and 0 failed.
# Test passed.
# /home/ollie/anaconda3/envs/py310_3/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2024-11-21 19:21:39.378712: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.378932: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.379083: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.463495: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.463670: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.463777: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2024-11-21 19:21:39.463906: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 19:21:39.464024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14912 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6

# %%
# !ln -s ../PtychoNN

# %%
probe.set_default_probe()


from ptycho import params as p
from ptycho import generate_data as init
# Out:
# DEBUG: Setting probe to tf.Tensor(
# [[[1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   ...
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]]
#
#  [[1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   ...
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]]
#
#  [[1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   ...
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]]
#
#  ...
#
#  [[1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   ...
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]]
#
#  [[1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   ...
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]]
#
#  [[1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   ...
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]
#   [1.0893617e-09+0.j]]], shape=(64, 64, 1), dtype=complex64) in params
#   0%|          | 0/161 [00:00<?, ?it/s]
# 101
# (16100, 64, 64, 1) (3600, 64, 64, 1)
# No cached result found. Calculating and caching the result.
# No cached result found. Calculating and caching the result.
# simulating gaussian position jitter, scale 0.0
# Using provided scan point offsets
# input shape (None, 64, 64, 1)
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/py310_3/lib/python3.10/site-packages/tensorflow_probability/python/distributions/distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# No cached result found. Calculating and caching the result.
# No cached result found. Calculating and caching the result.
# simulating gaussian position jitter, scale 0.0
# Using provided scan point offsets
# input shape (None, 64, 64, 1)
# discarding length 0 from test image
# DEBUG: generating grid-mode ground truth image
# 0.9999916

# %%
# init.ptycho_dataset.train_data.to_npz('lines_with_phase_1e9.npz')
# init.ptycho_dataset.train_data.to_npz('lines_with_phase_1e4.npz')
# init.ptycho_dataset.train_data.to_npz('lines_no_overlap.npz')

# %%
# init.ptycho_dataset.train_data.to_npz('cherukara_1e4_train.npz')
# init.ptycho_dataset.test_data.to_npz('cherukara_1e4_test.npz')
# init.ptycho_dataset.train_data.to_npz('cherukara_1e9_train.npz')
# init.ptycho_dataset.test_data.to_npz('cherukara_1e9_test.npz')

# %%
init.ptycho_dataset.train_data.Y.shape
# Out:
# TensorShape([2704, 64, 64, 4])

# %%
init.X_train.shape
# Out:
# (2704, 64, 64, 4)

# %% [markdown]
# ## Full PINN model, best params:

# %%
from ptycho import params as p
p.cfg['data_source'] = 'experimental'
p.cfg['offset'] = 4
p.cfg['max_position_jitter'] = 10
p.cfg['output_prefix'] = 'tmp'

p.cfg['gridsize'] = 2
p.cfg['n_filters_scale'] = 2
p.cfg['object.big'] = True
p.cfg['intensity_scale.trainable'] = True

from ptycho import train, model
# reload(model)
# reload(train)

# print(p.cfg)
from ptycho.train import *
# Out:
# DEBUG: Setting timestamp to 11/21/2024, 19:27:37 in params
# input shape (None, 64, 64, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 64, 64, 4)]          0         []
#
#  tf.math.truediv (TFOpLambd  (None, 64, 64, 4)            0         ['input[0][0]']
#  a)
#
#  conv2d (Conv2D)             (None, 64, 64, 64)           2368      ['tf.math.truediv[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 64)           0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)          147584    ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 128)          0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          590080    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 256)            0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)            295040    ['max_pooling2d_2[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 128)            295040    ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)            147584    ['conv2d_8[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)            147584    ['conv2d_14[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 128)          0         ['conv2d_9[0][0]']
#  D)
#
#  up_sampling2d_2 (UpSamplin  (None, 16, 16, 128)          0         ['conv2d_15[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)           73792     ['up_sampling2d[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 64)           73792     ['up_sampling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)           36928     ['conv2d_10[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 64)           36928     ['conv2d_16[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 64)           0         ['conv2d_11[0][0]']
#  g2D)
#
#  up_sampling2d_3 (UpSamplin  (None, 32, 32, 64)           0         ['conv2d_17[0][0]']
#  g2D)
#
#  tf.__operators__.getitem (  (None, 32, 32, 60)           0         ['up_sampling2d_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (None, 32, 32, 60)           0         ['up_sampling2d_3[0][0]']
#   (SlicingOpLambda)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 1)            541       ['tf.__operators__.getitem[0][
#                                                                     0]']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 4)            2164      ['tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
#  amp (Lambda)                (None, 32, 32, 1)            0         ['conv2d_6[0][0]']
#
#  phi (Lambda)                (None, 32, 32, 4)            0         ['conv2d_12[0][0]']
#
#  amp_padded (ZeroPadding2D)  (None, 64, 64, 1)            0         ['amp[0][0]']
#
#  phase_padded (ZeroPadding2  (None, 64, 64, 4)            0         ['phi[0][0]']
#  D)
#
#  obj (Lambda)                (None, 64, 64, 4)            0         ['amp_padded[0][0]',
#                                                                      'phase_padded[0][0]']
#
#  input_positions (InputLaye  [(None, 1, 2, 4)]            0         []
#  r)
#
#  padded_obj_2 (Lambda)       (None, 78, 78, 1)            0         ['obj[0][0]',
#                                                                      'input_positions[0][0]']
#
#  padded_objs_with_offsets (  (None, None, None, 1)        0         ['padded_obj_2[0][0]',
#  Lambda)                                                             'input_positions[0][0]']
#
#  probe_illumination (ProbeI  ((None, 64, 64, 1),          4096      ['padded_objs_with_offsets[0][
#  llumination)                 (1, 1, 64, 64, 1))                    0]']
#
#  pred_amplitude (Lambda)     ((None, 64, 64, 1),          0         ['probe_illumination[0][0]']
#                               (None, 64, 64, 1))
#
#  pred_diff_channels (Lambda  (None, 64, 64, 4)            0         ['pred_amplitude[0][1]']
#  )
#
#  tf.math.multiply (TFOpLamb  (None, 64, 64, 4)            0         ['pred_diff_channels[0][0]']
#  da)
#
#  trimmed_obj (Lambda)        (None, 64, 64, 1)            0         ['padded_obj_2[0][0]']
#
#  distribution_lambda (Distr  ((None, 64, 64, 4),          0         ['tf.math.multiply[0][0]']
#  ibutionLambda)               (None, 64, 64, 4))
#
# ==================================================================================================
# Total params: 2259473 (8.63 MB)
# Trainable params: 2255377 (8.60 MB)
# Non-trainable params: 4096 (32.00 KB)
# __________________________________________________________________________________________________
# None
# DEBUG: generate_data diff norm 0.05060917139053345
# DEBUG: Setting intensity_scale to 988.21173 in params
# DEBUG: Setting probe to tf.Tensor(
# [[[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  ...
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]], shape=(64, 64, 1), dtype=complex64) in params
# Current Parameters:
# --------------------
# N: 64
# amp_activation: sigmoid
# batch_size: 16
# bigN: 68
# big_gridsize: 10
# data_source: experimental
# debug: True
# default_probe_scale: 0.7
# gaussian_smoothing_sigma: 0.0
# gridsize: 2
# h5_path: wts.h5
# intensity_scale: 988.2117309570312
# intensity_scale.trainable: True
# label:
# mae_weight: 0.0
# max_position_jitter: 10
# model_type: pinn
# n_filters_scale: 2
# nepochs: 60
# nimgs_test: 1
# nimgs_train: 1
# nll_weight: 1.0
# nphotons: 1000000000.0
# npseed: 42
# object.big: True
# offset: 4
# outer_offset_test: 20
# outer_offset_train: 8
# output_prefix: tmp/11-21-2024-19.27.37_/
# pad_object: True
# positions.provided: False
# probe:
#   shape: (64, 64, 1)
#   mean: 0.100+0.000j
#   std: 0.296
#   min: 0.000+0.000j
#   max: 1.089+0.000j
# probe.big: False
# probe.mask: True
# probe.trainable: False
# probe_scale: 10.0
# realspace_mae_weight: 0.0
# realspace_weight: 0.0
# set_phi: True
# sim_jitter_scale: 0.0
# size: 392
# timestamp: 11/21/2024, 19:27:37
# tv_weight: 0.0
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2024-11-21 19:27:38.511913: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-11-21 19:27:38.511933: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-11-21 19:27:38.511952: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1883] Profiler found 1 GPUs
# 2024-11-21 19:27:38.544771: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:163] cuptiEnableCallback: error 1: CUPTI_ERROR_INVALID_PARAMETER
# 2024-11-21 19:27:38.544809: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:449] CuptiErrorManager is disabling profiling automatically.
# 2024-11-21 19:27:38.544813: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:449] CuptiErrorManager is disabling profiling automatically.
# 2024-11-21 19:27:38.544821: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-11-21 19:27:38.544825: E external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1941] function cupti_interface_->EnableCallback( 1 , subscriber_, CUPTI_CB_DOMAIN_DRIVER_API, cbid)failed with error
# 2024-11-21 19:27:38.544960: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-11-21 19:27:38.544974: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:153] cuptiEnableCallback: ignored due to a previous error.
# 2024-11-21 19:27:38.544978: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-11-21 19:27:38.544981: E external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1963] function cupti_interface_->EnableCallback( 0 , subscriber_, CUPTI_CB_DOMAIN_DRIVER_API, cbid)failed with error
# 2024-11-21 19:27:38.544987: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:142] cuptiFinalize: ignored due to a previous error.
# 2024-11-21 19:27:38.544990: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-11-21 19:27:38.544994: E external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:2026] function cupti_interface_->Finalize()failed with error
# Epoch 1/60
# input shape (None, 64, 64, 1)
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# input shape (None, 64, 64, 1)
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 2024-11-21 19:27:42.581180: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-11-21 19:27:42.581776: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x5e3b3ab46210
# 2024-11-21 19:27:43.973468: I external/local_xla/xla/service/service.cc:168] XLA service 0x78b052227580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-21 19:27:43.973504: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-11-21 19:27:43.976962: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732235264.041061  277383 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 161/161 [==============================] - ETA: 0s - loss: 335727744.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 20.0776 - distribution_lambda_loss: 335727744.0000input shape (None, 64, 64, 1)
# 161/161 [==============================] - 9s 20ms/step - loss: 335727744.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 20.0776 - distribution_lambda_loss: 335727744.0000 - val_loss: 258482048.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 20.2602 - val_distribution_lambda_loss: 258482048.0000 - lr: 0.0010
# Epoch 2/60
# 161/161 [==============================] - 2s 10ms/step - loss: 157791104.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 17.2739 - distribution_lambda_loss: 157791104.0000 - val_loss: 125763080.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 18.1984 - val_distribution_lambda_loss: 125763080.0000 - lr: 0.0010
# Epoch 3/60
# 161/161 [==============================] - 2s 10ms/step - loss: 82567416.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 14.9407 - distribution_lambda_loss: 82567416.0000 - val_loss: 63696104.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 15.1134 - val_distribution_lambda_loss: 63696104.0000 - lr: 0.0010
# Epoch 4/60
# 161/161 [==============================] - 2s 10ms/step - loss: 45062152.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 13.3466 - distribution_lambda_loss: 45062152.0000 - val_loss: 44666120.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 14.0761 - val_distribution_lambda_loss: 44666120.0000 - lr: 0.0010
# Epoch 5/60
# 161/161 [==============================] - 2s 10ms/step - loss: 31740156.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 12.3000 - distribution_lambda_loss: 31740156.0000 - val_loss: 38650716.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 13.2884 - val_distribution_lambda_loss: 38650716.0000 - lr: 0.0010
# Epoch 6/60
# 161/161 [==============================] - 2s 10ms/step - loss: 25805620.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 11.5979 - distribution_lambda_loss: 25805620.0000 - val_loss: 31094546.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 12.4662 - val_distribution_lambda_loss: 31094546.0000 - lr: 0.0010
# Epoch 7/60
# 161/161 [==============================] - 2s 10ms/step - loss: 22808526.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 11.0251 - distribution_lambda_loss: 22808526.0000 - val_loss: 26750886.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 11.7413 - val_distribution_lambda_loss: 26750886.0000 - lr: 0.0010
# Epoch 8/60
# 161/161 [==============================] - 2s 10ms/step - loss: 20451040.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 10.5828 - distribution_lambda_loss: 20451040.0000 - val_loss: 24422434.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 10.8118 - val_distribution_lambda_loss: 24422434.0000 - lr: 0.0010
# Epoch 9/60
# 161/161 [==============================] - 2s 10ms/step - loss: 18390982.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 10.1178 - distribution_lambda_loss: 18390982.0000 - val_loss: 24804344.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 11.2150 - val_distribution_lambda_loss: 24804344.0000 - lr: 0.0010
# Epoch 10/60
# 161/161 [==============================] - 2s 10ms/step - loss: 18244288.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 10.0196 - distribution_lambda_loss: 18244288.0000 - val_loss: 21006046.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 10.5807 - val_distribution_lambda_loss: 21006046.0000 - lr: 0.0010
# Epoch 11/60
# 161/161 [==============================] - 2s 10ms/step - loss: 16045820.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 9.6161 - distribution_lambda_loss: 16045820.0000 - val_loss: 19883442.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 10.3105 - val_distribution_lambda_loss: 19883442.0000 - lr: 0.0010
# Epoch 12/60
# 161/161 [==============================] - 2s 10ms/step - loss: 15691621.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 9.4014 - distribution_lambda_loss: 15691621.0000 - val_loss: 19925514.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 10.7785 - val_distribution_lambda_loss: 19925514.0000 - lr: 0.0010
# Epoch 13/60
# 161/161 [==============================] - 2s 10ms/step - loss: 14951099.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 9.1936 - distribution_lambda_loss: 14951099.0000 - val_loss: 18986690.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 10.1111 - val_distribution_lambda_loss: 18986690.0000 - lr: 0.0010
# Epoch 14/60
# 161/161 [==============================] - 2s 10ms/step - loss: 13847979.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 8
0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.7983 - val_distribution_lambda_loss: 12791414.0000 - lr: 2.5000e-04
# Epoch 28/60
# 161/161 [==============================] - 2s 10ms/step - loss: 8025880.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.4444 - distribution_lambda_loss: 8025880.5000 - val_loss: 12906741.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.8075 - val_distribution_lambda_loss: 12906741.0000 - lr: 2.5000e-04
# Epoch 29/60
# 161/161 [==============================] - 2s 10ms/step - loss: 7833770.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.3816 - distribution_lambda_loss: 7833770.0000 - val_loss: 12710677.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.7004 - val_distribution_lambda_loss: 12710677.0000 - lr: 2.5000e-04
# Epoch 30/60
# 161/161 [==============================] - 2s 10ms/step - loss: 7739708.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.3533 - distribution_lambda_loss: 7739708.0000 - val_loss: 12508753.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.6156 - val_distribution_lambda_loss: 12508753.0000 - lr: 2.5000e-04
# Epoch 31/60
# 161/161 [==============================] - 2s 10ms/step - loss: 7622976.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.3158 - distribution_lambda_loss: 7622976.0000 - val_loss: 12422722.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.7022 - val_distribution_lambda_loss: 12422722.0000 - lr: 2.5000e-04
# Epoch 32/60
# 161/161 [==============================] - 2s 10ms/step - loss: 7516438.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.2870 - distribution_lambda_loss: 7516438.5000 - val_loss: 12490389.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.6956 - val_distribution_lambda_loss: 12490389.0000 - lr: 2.5000e-04
# Epoch 33/60
# 157/161 [============================>.] - ETA: 0s - loss: 7375032.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.2099 - distribution_lambda_loss: 7375032.5000
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 161/161 [==============================] - 2s 10ms/step - loss: 7417175.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.2428 - distribution_lambda_loss: 7417175.5000 - val_loss: 12511409.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.7199 - val_distribution_lambda_loss: 12511409.0000 - lr: 2.5000e-04
# Epoch 34/60
# 161/161 [==============================] - 2s 10ms/step - loss: 7052913.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.1396 - distribution_lambda_loss: 7052913.0000 - val_loss: 12053852.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.5668 - val_distribution_lambda_loss: 12053852.0000 - lr: 1.2500e-04
# Epoch 35/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6928851.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.0992 - distribution_lambda_loss: 6928851.5000 - val_loss: 12033135.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4967 - val_distribution_lambda_loss: 12033135.0000 - lr: 1.2500e-04
# Epoch 36/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6854585.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.0769 - distribution_lambda_loss: 6854585.0000 - val_loss: 12015084.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.5348 - val_distribution_lambda_loss: 12015084.0000 - lr: 1.2500e-04
# Epoch 37/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6807145.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.0586 - distribution_lambda_loss: 6807145.5000 - val_loss: 11984807.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.5183 - val_distribution_lambda_loss: 11984807.0000 - lr: 1.2500e-04
# Epoch 38/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6739060.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.0359 - distribution_lambda_loss: 6739060.5000 - val_loss: 11871525.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.5083 - val_distribution_lambda_loss: 11871525.0000 - lr: 1.2500e-04
# Epoch 39/60
# 161/161 [==============================] - 2s 9ms/step - loss: 6686724.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.0189 - distribution_lambda_loss: 6686724.5000 - val_loss: 11870795.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4745 - val_distribution_lambda_loss: 11870795.0000 - lr: 1.2500e-04
# Epoch 40/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6645507.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 7.0027 - distribution_lambda_loss: 6645507.0000 - val_loss: 11808510.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4805 - val_distribution_lambda_loss: 11808510.0000 - lr: 1.2500e-04
# Epoch 41/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6571965.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.9848 - distribution_lambda_loss: 6571965.0000 - val_loss: 11740304.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.5679 - val_distribution_lambda_loss: 11740304.0000 - lr: 1.2500e-04
# Epoch 42/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6506201.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.9698 - distribution_lambda_loss: 6506201.0000 - val_loss: 11807142.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3661 - val_distribution_lambda_loss: 11807142.0000 - lr: 1.2500e-04
# Epoch 43/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6449968.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.9394 - distribution_lambda_loss: 6449968.0000 - val_loss: 11620782.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4313 - val_distribution_lambda_loss: 11620782.0000 - lr: 1.2500e-04
# Epoch 44/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6370326.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.9102 - distribution_lambda_loss: 6370326.5000 - val_loss: 11707154.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.5111 - val_distribution_lambda_loss: 11707154.0000 - lr: 1.2500e-04
# Epoch 45/60
# 157/161 [============================>.] - ETA: 0s - loss: 6344208.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.9051 - distribution_lambda_loss: 6344208.5000
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001.
# 161/161 [==============================] - 2s 10ms/step - loss: 6344473.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.9084 - distribution_lambda_loss: 6344473.5000 - val_loss: 11645966.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3960 - val_distribution_lambda_loss: 11645966.0000 - lr: 1.2500e-04
# Epoch 46/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6208640.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.8555 - distribution_lambda_loss: 6208640.0000 - val_loss: 11531172.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4233 - val_distribution_lambda_loss: 11531172.0000 - lr: 1.0000e-04
# Epoch 47/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6140827.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.8321 - distribution_lambda_loss: 6140827.5000 - val_loss: 11503736.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3957 - val_distribution_lambda_loss: 11503736.0000 - lr: 1.0000e-04
# Epoch 48/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6101474.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.8206 - distribution_lambda_loss: 6101474.0000 - val_loss: 11500361.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4274 - val_distribution_lambda_loss: 11500361.0000 - lr: 1.0000e-04
# Epoch 49/60
# 161/161 [==============================] - 2s 10ms/step - loss: 6038361.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.7994 - distribution_lambda_loss: 6038361.5000 - val_loss: 11451628.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4055 - val_distribution_lambda_loss: 11451628.0000 - lr: 1.0000e-04
# Epoch 50/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5990758.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.7815 - distribution_lambda_loss: 5990758.0000 - val_loss: 11498937.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3593 - val_distribution_lambda_loss: 11498937.0000 - lr: 1.0000e-04
# Epoch 51/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5948297.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.7666 - distribution_lambda_loss: 5948297.0000 - val_loss: 11499214.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3990 - val_distribution_lambda_loss: 11499214.0000 - lr: 1.0000e-04
# Epoch 52/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5923041.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.7596 - distribution_lambda_loss: 5923041.0000 - val_loss: 11402496.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3243 - val_distribution_lambda_loss: 11402496.0000 - lr: 1.0000e-04
# Epoch 53/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5912343.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.7508 - distribution_lambda_loss: 5912343.0000 - val_loss: 11402961.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4024 - val_distribution_lambda_loss: 11402961.0000 - lr: 1.0000e-04
# Epoch 54/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5795561.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.7098 - distribution_lambda_loss: 5795561.5000 - val_loss: 11261557.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3357 - val_distribution_lambda_loss: 11261557.0000 - lr: 1.0000e-04
# Epoch 55/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5762752.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.6945 - distribution_lambda_loss: 5762752.0000 - val_loss: 11344503.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.4053 - val_distribution_lambda_loss: 11344503.0000 - lr: 1.0000e-04
# Epoch 56/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5689338.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.6721 - distribution_lambda_loss: 5689338.5000 - val_loss: 11258603.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3124 - val_distribution_lambda_loss: 11258603.0000 - lr: 1.0000e-04
# Epoch 57/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5668929.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.6641 - distribution_lambda_loss: 5668929.0000 - val_loss: 11180808.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.2969 - val_distribution_lambda_loss: 11180808.0000 - lr: 1.0000e-04
# Epoch 58/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5638856.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.6527 - distribution_lambda_loss: 5638856.0000 - val_loss: 11275320.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3652 - val_distribution_lambda_loss: 11275320.0000 - lr: 1.0000e-04
# Epoch 59/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5552239.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.6224 - distribution_lambda_loss: 5552239.5000 - val_loss: 11208386.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.2913 - val_distribution_lambda_loss: 11208386.0000 - lr: 1.0000e-04
# Epoch 60/60
# 161/161 [==============================] - 2s 10ms/step - loss: 5527874.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 6.6097 - distribution_lambda_loss: 5527874.5000 - val_loss: 11227502.0000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 8.3411 - val_distribution_lambda_loss: 11227502.0000 - lr: 1.0000e-04
# DEBUG: Setting probe to tf.Tensor(
# [[[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  ...
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]
#
#  [[1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   ...
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]
#   [1.0893618e-09+0.j]]], shape=(64, 64, 1), dtype=complex64) in params
# INFO: setting probe from test data container. It MUST be consistent with the training probe
# input shape (None, 64, 64, 1)
# 12/12 [==============================] - 2s 66ms/step
# subtracting mean -0.22659217
# subtracting mean 0.840752
# mean scale adjustment: 0.22736177
# mean scale adjustment: 0.22736177
# performed by index method
# performed by index method
# performed by index method
# mean scale adjustment: 1
# mean scale adjustment: 1
# performed by index method
# performed by index method
# performed by index method
# subtracting mean -0.22659217
# subtracting mean 0.840752
# mean scale adjustment: 0.22736177
# mean scale adjustment: 0.22736177
# performed by index method
# performed by index method
# performed by index method
# mean scale adjustment: 1
# mean scale adjustment: 1
# performed by index method
# performed by index method
# performed by index method
# input shape (None, 64, 64, 1)
# input shape (None, 64, 64, 1)
# input shape (None, 64, 64, 1)
# input shape (None, 64, 64, 1)
# input shape (None, 64, 64, 1)
# INFO:tensorflow:Assets written to: tmp/11-21-2024-19.27.37_//wts.h5_autoencoder/assets
# INFO:tensorflow:Assets written to: tmp/11-21-2024-19.27.37_//wts.h5_autoencoder/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: tmp/11-21-2024-19.27.37_//wts.h5_diffraction_to_obj/assets
# INFO:tensorflow:Assets written to: tmp/11-21-2024-19.27.37_//wts.h5_diffraction_to_obj/assets

# %%
from ptycho import train_pinn

# %%
d = save_metrics(stitched_obj, YY_ground_truth, label = 'PINN,NLL,overlaps')
d
#d0 = d
# Out:
# subtracting mean -0.2224143
# subtracting mean 0.840752
# mean scale adjustment: 0.2274445
# mean scale adjustment: 0.2274445
# performed by index method
# performed by index method
# performed by index method
# mean scale adjustment: 1
# mean scale adjustment: 1
# performed by index method
# performed by index method
# performed by index method
# {'mae': (0.0036731628, 0.16842197),
#  'mse': (2.955757e-05, 0.06852974),
#  'psnr': (93.42411603877278, 59.77201267129571),
#  'frc50': (36, 34),
#  'frc': (array([0.99618063, 0.99259338, 0.99025605, 0.98732977, 0.97803013,
#          0.96719896, 0.95638145, 0.93000352, 0.89328704, 0.86264444,
#          0.83539308, 0.81338029, 0.80853209, 0.80120721, 0.79062609,
#          0.80616965, 0.82921225, 0.8383096 , 0.83936971, 0.85052624,
#          0.86051645, 0.86577231, 0.86916765, 0.8685448 , 0.85719328,
#          0.83918977, 0.81466654, 0.79445868, 0.78369473, 0.76244836,
#          0.7420733 , 0.72702593, 0.67822448, 0.61561407, 0.57064105,
#          0.52564849, 0.47313478, 0.41100087, 0.35289465, 0.27868631,
#          0.22240831, 0.20551883, 0.19743565, 0.17738571, 0.16701807,
#          0.16478919, 0.16520595, 0.16556745, 0.14468268, 0.09024951,
#          0.05304549, 0.0669063 , 0.10738326, 0.14942881, 0.18539589,
#          0.17843474, 0.13810836, 0.13428828, 0.17437807, 0.20905116,
#          0.21904027, 0.20357073, 0.18567288, 0.19238231, 0.20655214,
#          0.21659696, 0.23787829, 0.23216383, 0.19790255, 0.18064779,
#          0.55510892, 0.51150956, 0.49166021, 0.51416772, 0.55921172,
#          0.55341052, 0.51324143, 0.52442438, 0.5355403 , 0.51492835,
#          0.49082061, 0.48113735, 0.51760026, 0.57780635, 0.58799182,
#          0.55588571, 0.54453232, 0.56167424, 0.59275223, 0.6078857 ,
#          0.58260146, 0.56173308, 0.57092677, 0.5833239 , 0.58424666,
#          0.55508593, 0.53436921, 0.53845172, 0.53195166, 0.49994519,
#          0.46916451, 0.47769322, 0.51942136, 0.54284317, 0.53937246,
#          0.53437768, 0.54871784, 0.58233165, 0.60722713, 0.60113746,
#          0.57551462, 0.55317723, 0.51220251, 0.39890173, 0.24517956,
#          0.14481355, 0.08966048, 0.0441202 , 0.01822786, 0.00943013,
#          0.01038839, 0.02116606, 0.03080417, 0.03001297, 0.02774547,
#          0.02630389, 0.03611481, 0.04706912, 0.04226977, 0.03988217,
#          0.04846198, 0.04918822, 0.05492275, 0.07283186, 0.07385085,
#          0.06326183, 0.06471084, 0.07112592, 0.07318008, 0.08483528,
#          0.09584196, 0.09137598, 0.09385696, 0.09857616, 0.13174833,
#          0.17180509, 0.15601266, 0.15787628, 0.21588807, 0.22231509,
#          0.28182909, 0.54922023, 0.81621418]))}

# %%
np.abs(stitched_obj[0]).std(), np.angle(stitched_obj[0]).std()
# Out:
# (0.041475322, 0.7093881)

# %%
# 1e4
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# reconstructed amplitude images
img1 = axs[0, 0].imshow(np.absolute(stitched_obj)[0], cmap='jet', interpolation='none')
axs[0, 0].set_title('Reconstructed amplitude')

# reconstructed phase images
axs[0, 1].imshow(np.angle(stitched_obj)[0], cmap='jet')
fig.colorbar(img1, ax=axs[0, 1])
axs[0, 1].set_title('Reconstructed phase')

# ground truth amplitude images
img = axs[1, 0].imshow(np.absolute(init.YY_ground_truth), interpolation='none', cmap='jet')
axs[1, 0].set_title('Ground truth amplitude')

# ground truth phase images
img = axs[1, 1].imshow(np.angle(init.YY_ground_truth), interpolation='none', cmap='jet')
axs[1, 1].set_title('Ground truth phase')
fig.colorbar(img, ax=axs[1, 1])

# %%
# 1e9
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# reconstructed amplitude images
img1 = axs[0, 0].imshow(np.absolute(stitched_obj)[0], cmap='jet', interpolation='none')
axs[0, 0].set_title('Reconstructed amplitude')

# reconstructed phase images
axs[0, 1].imshow(np.angle(stitched_obj)[0], cmap='jet')
fig.colorbar(img1, ax=axs[0, 1])
axs[0, 1].set_title('Reconstructed phase')

# ground truth amplitude images
img = axs[1, 0].imshow(np.absolute(init.YY_ground_truth), interpolation='none', cmap='jet')
axs[1, 0].set_title('Ground truth amplitude')

# ground truth phase images
img = axs[1, 1].imshow(np.angle(init.YY_ground_truth), interpolation='none', cmap='jet')
axs[1, 1].set_title('Ground truth phase')
fig.colorbar(img, ax=axs[1, 1])

# %%
from ptycho import evaluation
idxs = list(range(0, 40, 10))
ptychopinn_heatmaps = [evaluation.summarize(i, pred_amp, reconstructed_obj,
                    X_test, Y_I_test, Y_phi_test, np.absolute(p.get('probe'))[:, :, 0], 0) for i in idxs]
# Out:
# phase min: -2.3676698 phase max: 0.6359483
# phase min: -2.3676698 phase max: 0.6359483
# /home/ollie/anaconda3/envs/py310_3/lib/python3.10/site-packages/ptycho/evaluation.py:81: RuntimeWarning: divide by zero encountered in log
#   true_diffraction = np.log(cfg.get('intensity_scale') * X_test)[i, :, :, channel]
# phase min: -2.3676698 phase max: 0.6359483
# phase min: -2.3676698 phase max: 0.6359483

# %%
from ptycho import evaluation
idxs = list(range(0, 40, 10))
ptychopinn_heatmaps = [evaluation.summarize(i, pred_amp, reconstructed_obj,
                    X_test, Y_I_test, Y_phi_test, np.absolute(p.get('probe'))[:, :, 0], 0) for i in idxs]
# Out:
# phase min: -2.3988416 phase max: 0.5536647
# phase min: -2.3988416 phase max: 0.5536647
# /home/ollie/anaconda3/envs/py310_3/lib/python3.10/site-packages/ptycho/evaluation.py:81: RuntimeWarning: divide by zero encountered in log
#   true_diffraction = np.log(cfg.get('intensity_scale') * X_test)[i, :, :, channel]
# phase min: -2.3988416 phase max: 0.5536647
# phase min: -2.3988416 phase max: 0.5536647

# %%
from ptycho import params as p
p.cfg['gridsize'] = 1
p.cfg['n_filters_scale'] = 1
p.cfg['set_phi'] = True

from ptycho.generate_data import *

from ptycho import baselines as bl
from ptycho import tf_helper as hh

reload(bl)

baseline_model, history = bl.train((X_train[:, :, :, :1]), Y_I_train[:, :, :, :1], Y_phi_train[:, :, :, :1])

plt.rcParams["figure.figsize"] = (10, 10)

baseline_pred_I, baseline_pred_phi = baseline_model.predict([X_test[:, :, :, 0]])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)           9248      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 32)           0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)           18496     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)           36928     ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 64)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)          73856     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)          147584    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 128)            0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)            147584    ['max_pooling2d_2[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 128)            147584    ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 128)            147584    ['conv2d_6[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 128)            147584    ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 128)          0         ['conv2d_7[0][0]']
#  D)
#
#  up_sampling2d_3 (UpSamplin  (None, 16, 16, 128)          0         ['conv2d_14[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)           73792     ['up_sampling2d[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)           73792     ['up_sampling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)           36928     ['conv2d_8[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 64)           36928     ['conv2d_15[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 64)           0         ['conv2d_9[0][0]']
#  g2D)
#
#  up_sampling2d_4 (UpSamplin  (None, 32, 32, 64)           0         ['conv2d_16[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 32)           18464     ['up_sampling2d_1[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 32)           18464     ['up_sampling2d_4[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)           9248      ['conv2d_10[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)           9248      ['conv2d_17[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 32)           0         ['conv2d_11[0][0]']
#  g2D)
#
#  up_sampling2d_5 (UpSamplin  (None, 64, 64, 32)           0         ['conv2d_18[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 1)            289       ['up_sampling2d_2[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 1)            289       ['up_sampling2d_5[0][0]']
#
# ==================================================================================================
# Total params: 1154210 (4.40 MB)
# Trainable params: 1154210 (4.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/60
# 81/81 [==============================] - 6s 23ms/step - loss: 0.6699 - conv2d_12_loss: 0.0336 - conv2d_19_loss: 0.6363 - val_loss: 0.5519 - val_conv2d_12_loss: 0.0131 - val_conv2d_19_loss: 0.5387 - lr: 0.0010
# Epoch 2/60
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5342 - conv2d_12_loss: 0.0098 - conv2d_19_loss: 0.5244 - val_loss: 0.5365 - val_conv2d_12_loss: 0.0073 - val_conv2d_19_loss: 0.5292 - lr: 0.0010
# Epoch 3/60
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5212 - conv2d_12_loss: 0.0071 - conv2d_19_loss: 0.5142 - val_loss: 0.5271 - val_conv2d_12_loss: 0.0063 - val_conv2d_19_loss: 0.5208 - lr: 0.0010
# Epoch 4/60
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5113 - conv2d_12_loss: 0.0103 - conv2d_19_loss: 0.5010 - val_loss: 0.5015 - val_conv2d_12_loss: 0.0063 - val_conv2d_19_loss: 0.4952 - lr: 0.0010
# Epoch 5/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.
- conv2d_12_loss: 0.0040 - conv2d_19_loss: 0.2394 - val_loss: 0.3381 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.3336 - lr: 1.2500e-04
# Epoch 45/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2405 - conv2d_12_loss: 0.0040 - conv2d_19_loss: 0.2365 - val_loss: 0.3378 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3333 - lr: 1.2500e-04
# Epoch 46/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2367 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.2328 - val_loss: 0.3367 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3321 - lr: 1.2500e-04
# Epoch 47/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2338 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.2299 - val_loss: 0.3373 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3327 - lr: 1.2500e-04
# Epoch 48/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2319 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.2280 - val_loss: 0.3365 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3320 - lr: 1.2500e-04
# Epoch 49/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2298 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.2258 - val_loss: 0.3367 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3322 - lr: 1.2500e-04
# Epoch 50/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2282 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.2243 - val_loss: 0.3348 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3303 - lr: 1.2500e-04
# Epoch 51/60
# 81/81 [==============================] - 1s 8ms/step - loss: 0.2248 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.2210 - val_loss: 0.3385 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3340 - lr: 1.2500e-04
# Epoch 52/60
# 77/81 [===========================>..] - ETA: 0s - loss: 0.2226 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.2188
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001.
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2228 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.2190 - val_loss: 0.3367 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3323 - lr: 1.2500e-04
# Epoch 53/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2195 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.2157 - val_loss: 0.3398 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3354 - lr: 1.0000e-04
# Epoch 54/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2166 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.2128 - val_loss: 0.3369 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.3325 - lr: 1.0000e-04
# Epoch 55/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2146 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.2108 - val_loss: 0.3400 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.3355 - lr: 1.0000e-04
# Epoch 56/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2130 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.2092 - val_loss: 0.3390 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.3346 - lr: 1.0000e-04
# Epoch 57/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2119 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.2082 - val_loss: 0.3371 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.3326 - lr: 1.0000e-04
# Epoch 58/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2092 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.2055 - val_loss: 0.3382 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.3338 - lr: 1.0000e-04
# Epoch 59/60
# 81/81 [==============================] - 1s 9ms/step - loss: 0.2068 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.2032 - val_loss: 0.3355 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.3311 - lr: 1.0000e-04
# Epoch 60/60
# 81/81 [==============================] - 1s 8ms/step - loss: 0.2063 - conv2d_12_loss: 0.0036 - conv2d_19_loss: 0.2027 - val_loss: 0.3363 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.3320 - lr: 1.0000e-04
# 12/12 [==============================] - 0s 15ms/step

# %%
from ptycho.data_preprocessing import stitch_data as stitch

# %%
baseline_stitched = stitch(baseline_pred_I, norm_Y_I_test)

plt.imshow(baseline_stitched[0], cmap = 'jet')#, vmin = vmin, vmax = vmax)

# %%
baseline_stitched = stitch(baseline_pred_I, norm_Y_I_test)

plt.imshow(baseline_stitched[0], cmap = 'jet')#, vmin = vmin, vmax = vmax)

# %%
baseline_stitched = stitch(baseline_pred_I, norm_Y_I_test)

plt.imshow(baseline_stitched[0], cmap = 'jet')#, vmin = vmin, vmax = vmax)

# %%
baseline_stitched = stitch(baseline_pred_I, norm_Y_I_test)

plt.imshow(baseline_stitched[0], cmap = 'jet')#, vmin = vmin, vmax = vmax)

# %%
from ptycho import evaluation
idxs = list(range(0, 100, 10))
ptychopinn_heatmaps = [evaluation.summarize(i, pred_amp, reconstructed_obj,
                    X_test, Y_I_test, Y_phi_test, np.absolute(p.get('probe'))[:, :, 0], 0) for i in idxs]

# %%
from ptycho import evaluation

evaluation.plt_metrics(history, metric2 = 'trimmed_obj_loss')

# %% [markdown]
# ## PINN, NLL, no overlap:

# %%
from ptycho import train_pinn

# %%
p.cfg['gridsize'] = 1
p.cfg['nll_weight'] = 1.
p.cfg['mae_weight'] = 0.

reload(init)
reload(train.model)
reload(train_pinn)

# print(p.cfg)
from ptycho.generate_data import *
from ptycho.train import *;

# %%
from ptycho.generate_data import *
X_test.shape

# %%
from ptycho import evaluation
pinn_heatmaps = [evaluation.summarize(i, train_pinn.pred_amp, train_pinn.reconstructed_obj,
                    X_test, Y_I_test, Y_phi_test, np.absolute(p.get('probe'))[:, :, 0], 0) for i in idxs]

# %%
img_dict_ptychopinn = ptychopinn_heatmaps[0]
img_dict_pinn = pinn_heatmaps[0]

img_dict_pinn.keys()

# %% [markdown]
# # Compare reconstructions of PINN with and without overlaps

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.size'] = 10

fig, axs = plt.subplots(2, 3, figsize=(7.5, 5))

# Slicing for central 32x32 region
slice_32x32 = slice(img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 - 16, 
                    img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 + 16)

# Top row for diffraction
axs[0, 0].imshow(img_dict_ptychopinn['true_diffraction'], cmap='jet')
axs[0, 0].set_title('True diffraction')
axs[0, 0].axis('off')

axs[0, 1].imshow(img_dict_ptychopinn['rec_diffraction'], cmap='jet')
axs[0, 1].set_title('PtychoPINN: \n reconstructed diffraction')
axs[0, 1].axis('off')

axs[0, 2].imshow(img_dict_pinn['rec_diffraction'], cmap='jet')
axs[0, 2].set_title('PINN: \n reconstructed diffraction')
axs[0, 2].axis('off')

# Bottom row for amplitude
axs[1, 0].imshow(img_dict_ptychopinn['true_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 0].set_title('True amplitude')
axs[1, 0].axis('off')

axs[1, 1].imshow(img_dict_ptychopinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 1].set_title('PtychoPINN: \n reconstructed amplitude')
axs[1, 1].axis('off')

axs[1, 2].imshow(img_dict_pinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 2].set_title('PINN: \n reconstructed amplitude')
axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from matplotlib import rcParams

matplotlib.rcParams['font.size'] = 11
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Computer Modern']

fig, axs = plt.subplots(2, 3, figsize=(7.5, 5))

# Slicing for central 32x32 region
slice_32x32 = slice(img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 - 16, 
                    img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 + 16)

# Save true_diffraction as a variable for easier subtraction
true_diffraction = img_dict_ptychopinn['true_diffraction']

# Calculate difference for PtychoPINN and PINN

diff_ptychopinn = np.log(
    np.abs(np.exp(img_dict_ptychopinn['rec_diffraction']) - np.exp(true_diffraction) * intensity_scale)
)
diff_pinn = np.log(
    np.abs(np.exp(img_dict_pinn['rec_diffraction']) - np.exp(true_diffraction) * intensity_scale)
)

# Calculate vmin and vmax (use highest non-infinite value if vmax is np.inf)
vmin = 0#np.minimum(np.min(diff_ptychopinn), np.min(diff_pinn))

# Replace np.inf with a large finite number for max
max_ptychopinn = np.max(diff_ptychopinn[np.isfinite(diff_ptychopinn)]) if np.isinf(np.max(diff_ptychopinn)) else np.max(diff_ptychopinn)
max_pinn = np.max(diff_pinn[np.isfinite(diff_pinn)]) if np.isinf(np.max(diff_pinn)) else np.max(diff_pinn)
vmax = np.maximum(max_ptychopinn, max_pinn)

# Top row for diffraction
im1 = axs[0, 0].imshow(true_diffraction + np.log(intensity_scale), cmap='jet')
axs[0, 0].set_title('True diffraction \n (log)')
axs[0, 0].axis('off')
fig.colorbar(im1, ax=axs[0, 0])

im2 = axs[0, 1].imshow(diff_ptychopinn, cmap='jet', vmin=vmin, vmax=vmax)
axs[0, 1].set_title('PtychoPINN: diffraction \n error (log absolute)')
axs[0, 1].axis('off')
fig.colorbar(im2, ax=axs[0, 1])

im3 = axs[0, 2].imshow(diff_pinn, cmap='jet', vmin=vmin, vmax=vmax)
axs[0, 2].set_title('PINN: diffraction \n error (log absolute)')
axs[0, 2].axis('off')
fig.colorbar(im3, ax=axs[0, 2])

# Bottom row for amplitude
axs[1, 0].imshow(img_dict_ptychopinn['true_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 0].set_title('True amplitude')
axs[1, 0].axis('off')

axs[1, 1].imshow(img_dict_ptychopinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 1].set_title('PtychoPINN: \n reconstructed amplitude')
axs[1, 1].axis('off')

axs[1, 2].imshow(img_dict_pinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 2].set_title('PINN: \n reconstructed amplitude')
axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
def normed_ff_np(arr):
    return (f.fftshift(np.absolute(f.fft2(np.array(arr)))) / np.sqrt(h * w))

# %%
from ptycho import fourier as f

# %% [markdown]
# # More real- and diffraction-space reconstructions

# %%
# !ln ../xrd_clustering/notebooks/visualization.py
from ptycho import visualization as vis
reload(vis)

off = 5
i = 0

vmin = np.min(Y_I_test[:, 16:-16, 16:-16][i:i + off])
vmax = np.max(Y_I_test[:, 16:-16, 16:-16][i:i + off])

print('diffraction reconstruction')
vis.display_imgs(np.log(np.absolute(pred_amp[:, :, :, 0]))[i:i + off])

print('diffraction ground truth')
vis.display_imgs(np.log(np.absolute(X_test[:, :, :, 0]))[i:i + off])

print('object reconstruction (amp)')
vis.display_imgs(np.absolute(reconstructed_obj[:, 16:-16, 16:-16, 0])[i:i + off], vmin = vmin, vmax = vmax)
# print('object reconstruction (phase)')
# vis.display_imgs(np.angle(b[:, 16:-16, 16:-16, 0])[i:i + 10])#, vmin = vmin, vmax = vmax)
print('object ground truth')
vis.display_imgs(Y_I_test[:, 16:-16, 16:-16, 0][i:i + off], vmin = vmin, vmax = vmax)

# %%
plt.rcParams["figure.figsize"] = (10, 5)


plt.subplot(2, 3, 1)

plt.imshow(Y_I_train[0, :, :, 0], cmap = 'jet')

plt.subplot(2, 3, 2)
plt.imshow(np.absolute(model.autoencoder.variables[-1]), cmap = 'jet')
# plt.colorbar()


plt.subplot(2, 3, 4)
plt.imshow(np.absolute(reconstructed_obj[100, :, :, 0]), cmap = 'jet')

plt.subplot(2, 3, 5)
tmp = np.absolute(f.fftshift(f.fft2(np.array(model.autoencoder.variables[-1][:, :, 0]))))
plt.imshow(np.log(tmp),
          cmap  ='jet')

plt.subplot(2, 3, 6)
plt.imshow(np.log(X_train[0, :, :, 0]), cmap = 'jet')

# for i, v in enumerate(model.autoencoder.variables):
#     print(i, v.shape)

# %%
plt.rcParams["figure.figsize"] = (5, 5)
Itest = (X_test * p.get('intensity_scale'))**2
print(Itest.shape, np.max(Itest, axis = 1).max(axis = 1).mean())

plt.imshow(np.log(np.sqrt(Itest[0, :, :, 0])), cmap = 'jet')
plt.colorbar()
