# %%
# !python ptycho/simtrain.py 4
# Out:
# /bin/bash: /home/ollie/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Traceback (most recent call last):
#   File "/home/ollie/Documents/scratch/ptycho/notebooks/ptycho/simtrain.py", line 3, in <module>
#     from . import datasets
# ImportError: attempted relative import with no known parent package

# %%
# from glob import glob

# prefixes = glob('outputs/*/')

# params_paths = glob('outputs/*/params.dill')

# hpaths = glob('outputs/*/history.dill')

# def load_dill(path):
#     with open(path, 'rb') as f:
#         return dill.load(f)

# import dill

# params = [load_dill(p) for p in params_paths]

# import pandas as pd
# import matplotlib.pyplot as plt
# histories =  pd.DataFrame({pdict['offset']: load_dill(p)['val_loss'] for pdict, p in zip(params, hpaths)}).sort_index(axis =1)

# %%
# params[2]['offset']

# import sys
# import argparse

# sys.argv = ['2']

# %%
from ptycho import params as p
p.cfg['offset'] = 6
p.cfg['nepochs'] = 10
p.cfg['output_prefix'] = 'tmp'
p.cfg
# Out:
# {'N': 64,
#  'offset': 6,
#  'gridsize': 2,
#  'bigoffset': 4,
#  'batch_size': 16,
#  'nepochs': 10,
#  'h': 64,
#  'w': 64,
#  'intensity_scale.trainable': False,
#  'probe.trainable': False,
#  'n_filters_scale': 2,
#  'output_prefix': 'tmp'}

# %%
from ptycho.simtrain import *
# Out:
# /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-02-06 20:24:26.063589: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 20:24:26.160304: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-02-06 20:24:26.490952: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/ollie/anaconda3/envs/tf/lib/
# 2023-02-06 20:24:26.490994: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/ollie/anaconda3/envs/tf/lib/
# 2023-02-06 20:24:26.490997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# 2023-02-06 20:24:27.424002: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:27.441730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:27.441862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:27.657816: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 20:24:27.659039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:27.659212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:27.659323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:28.029451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:28.029603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:28.029716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-06 20:24:28.029788: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2023-02-06 20:24:28.029881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21859 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Using provided scan point offsets
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow_probability-0.18.0-py3.9.egg/tensorflow_probability/python/distributions/distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow_probability-0.18.0-py3.9.egg/tensorflow_probability/python/distributions/distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# Using provided scan point offsets
# 0.99999183
# nphoton 8.97497
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 64, 64, 4)]  0           []
#
#  intensity_scaler (IntensitySca  (None, 64, 64, 4)   1           ['input[0][0]']
#  ler)
#
#  conv2d (Conv2D)                (None, 64, 64, 64)   2368        ['intensity_scaler[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    590080      ['max_pooling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_11[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 256)  0           ['conv2d_7[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 256)  0          ['conv2d_12[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 128)  295040      ['up_sampling2d[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  295040      ['up_sampling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_8[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_13[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_9[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_14[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 4)    4612        ['up_sampling2d_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 4)    4612        ['up_sampling2d_3[0][0]']
#
#  amp (Lambda)                   (None, 32, 32, 4)    0           ['conv2d_10[0][0]']
#
#  phi (Lambda)                   (None, 32, 32, 4)    0           ['conv2d_15[0][0]']
#
#  obj (Lambda)                   (None, 32, 32, 4)    0           ['amp[0][0]',
#                                                                   'phi[0][0]']
#
#  padded_obj (ZeroPadding2D)     (None, 64, 64, 4)    0           ['obj[0][0]']
#
#  input_positions (InputLayer)   [(None, 1, 2, 4)]    0           []
#
#  padded_obj_2 (Lambda)          (None, 70, 70, 1)    0           ['padded_obj[0][0]',
#                                                                   'input_positions[0][0]']
#
#  padded_objs_with_offsets (Lamb  (None, None, None,   0          ['padded_obj_2[0][0]',
#  da)                            1)                                'input_positions[0][0]']
#
#  probe_illumination (ProbeIllum  ((None, 64, 64, 1),  4096       ['padded_objs_with_offsets[0][0]'
#  ination)                        (1, 64, 64, 1))                 ]
#
#  pred_amplitude (Lambda)        ((None, 64, 64, 1),  0           ['probe_illumination[0][0]']
#                                  (None, 64, 64, 1))
#
#  pred_diff_channels (Lambda)    (None, 64, 64, 4)    0           ['pred_amplitude[0][1]']
#
#  intensity_scaler_inv (Intensit  (None, 64, 64, 4)   1           ['pred_diff_channels[0][0]']
#  yScaler_inv)
#  trimmed_obj (Lambda)           (None, 64, 64, 1)    0           ['padded_obj_2[0][0]']
#
#  distribution_lambda (Distribut  ((None, 64, 64, 4),  0          ['intensity_scaler_inv[0][0]']
#  ionLambda)                      (None, 64, 64, 4))
#
# ==================================================================================================
# Total params: 4,404,873
# Trainable params: 4,400,776
# Non-trainable params: 4,097
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2023-02-06 20:26:00.379881: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-02-06 20:26:00.379896: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2023-02-06 20:26:00.379924: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1664] Profiler found 1 GPUs
# 2023-02-06 20:26:00.380883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/ollie/anaconda3/envs/tf/lib/
# 2023-02-06 20:26:00.458795: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2023-02-06 20:26:00.458892: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed
# Epoch 1/10
# 2023-02-06 20:26:06.834040: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-02-06 20:26:07.942803: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x1c0eed60
# 813/813 [==============================] - 14s 14ms/step - loss: 62534512.0000 - trimmed_obj_loss: 0.1621 - pred_diff_channels_loss: 85.3501 - distribution_lambda_loss: 62534512.0000 - probe_illumination_loss: 0.0047 - val_loss: 33394626.0000 - val_trimmed_obj_loss: 0.1554 - val_pred_diff_channels_loss: 84.6205 - val_distribution_lambda_loss: 33394626.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 2/10
# 813/813 [==============================] - 10s 12ms/step - loss: 20363898.0000 - trimmed_obj_loss: 0.1547 - pred_diff_channels_loss: 85.3494 - distribution_lambda_loss: 20363898.0000 - probe_illumination_loss: 0.0047 - val_loss: 16057097.0000 - val_trimmed_obj_loss: 0.1543 - val_pred_diff_channels_loss: 84.6188 - val_distribution_lambda_loss: 16057097.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 3/10
# 813/813 [==============================] - 10s 12ms/step - loss: 17736162.0000 - trimmed_obj_loss: 0.1524 - pred_diff_channels_loss: 85.3492 - distribution_lambda_loss: 17736162.0000 - probe_illumination_loss: 0.0047 - val_loss: 15675171.0000 - val_trimmed_obj_loss: 0.1496 - val_pred_diff_channels_loss: 84.6194 - val_distribution_lambda_loss: 15675171.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 4/10
# 813/813 [==============================] - 10s 12ms/step - loss: 17008684.0000 - trimmed_obj_loss: 0.1505 - pred_diff_channels_loss: 85.3492 - distribution_lambda_loss: 17008684.0000 - probe_illumination_loss: 0.0047 - val_loss: 13132396.0000 - val_trimmed_obj_loss: 0.1484 - val_pred_diff_channels_loss: 84.6190 - val_distribution_lambda_loss: 13132396.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 5/10
# 813/813 [==============================] - 10s 12ms/step - loss: 13143394.0000 - trimmed_obj_loss: 0.1479 - pred_diff_channels_loss: 85.3490 - distribution_lambda_loss: 13143394.0000 - probe_illumination_loss: 0.0047 - val_loss: 10963433.0000 - val_trimmed_obj_loss: 0.1476 - val_pred_diff_channels_loss: 84.6188 - val_distribution_lambda_loss: 10963433.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 6/10
# 813/813 [==============================] - 10s 12ms/step - loss: 12129096.0000 - trimmed_obj_loss: 0.1474 - pred_diff_channels_loss: 85.3491 - distribution_lambda_loss: 12129096.0000 - probe_illumination_loss: 0.0047 - val_loss: 14229655.0000 - val_trimmed_obj_loss: 0.1447 - val_pred_diff_channels_loss: 84.6197 - val_distribution_lambda_loss: 14229655.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 7/10
# 813/813 [==============================] - 10s 12ms/step - loss: 10171489.0000 - trimmed_obj_loss: 0.1464 - pred_diff_channels_loss: 85.3492 - distribution_lambda_loss: 10171489.0000 - probe_illumination_loss: 0.0047 - val_loss: 8810376.0000 - val_trimmed_obj_loss: 0.1441 - val_pred_diff_channels_loss: 84.6188 - val_distribution_lambda_loss: 8810376.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 8/10
# 813/813 [==============================] - 10s 12ms/step - loss: 9512393.0000 - trimmed_obj_loss: 0.1446 - pred_diff_channels_loss: 85.3491 - distribution_lambda_loss: 9512393.0000 - probe_illumination_loss: 0.0047 - val_loss: 8042230.0000 - val_trimmed_obj_loss: 0.1434 - val_pred_diff_channels_loss: 84.6189 - val_distribution_lambda_loss: 8042230.0000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 9/10
# 813/813 [==============================] - 10s 12ms/step - loss: 8301715.5000 - trimmed_obj_loss: 0.1438 - pred_diff_channels_loss: 85.3490 - distribution_lambda_loss: 8301715.5000 - probe_illumination_loss: 0.0047 - val_loss: 7115023.5000 - val_trimmed_obj_loss: 0.1431 - val_pred_diff_channels_loss: 84.6190 - val_distribution_lambda_loss: 7115023.5000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# Epoch 10/10
# 813/813 [==============================] - 10s 12ms/step - loss: 7474385.0000 - trimmed_obj_loss: 0.1432 - pred_diff_channels_loss: 85.3491 - distribution_lambda_loss: 7474385.0000 - probe_illumination_loss: 0.0047 - val_loss: 5943093.5000 - val_trimmed_obj_loss: 0.1436 - val_pred_diff_channels_loss: 84.6189 - val_distribution_lambda_loss: 5943093.5000 - val_probe_illumination_loss: 0.0047 - lr: 0.0010
# 143/143 [==============================] - 8s 54ms/step
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.

# %%
from ptycho.simtrain import *

# %%
intensity_scale
# Out:
# 2531.8667

# %%
# Offset 4
from ptycho import evaluation
evaluation.summarize(10, a, b, X_test, Y_I_test, Y_phi_test, probe.probe, 0)
# Out:
# phase min: -0.042237002 phase max: 0.04039675
# /home/ollie/Documents/scratch/ptycho/notebooks/ptycho/evaluation.py:57: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(X_test)[i, :, :, channel], cmap = 'jet')

# %%
# Offset 4
from ptycho import evaluation
evaluation.summarize(10, a, b, X_test, Y_I_test, Y_phi_test, probe.probe, 0)
# Out:
# phase min: -0.1031101 phase max: 0.093181916
# /home/ollie/Documents/scratch/ptycho/notebooks/ptycho/evaluation.py:57: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(X_test)[i, :, :, channel], cmap = 'jet')

# %%
YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright].shape
# Out:
# (333, 333, 1)

# %%
bordersize = N // 2 - bigoffset // 4
clipsize = (bordersize + ((gridsize - 1) * offset) // 2)

plt.imshow(YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright], interpolation = 'none',
          cmap = 'jet')
vmin = np.min(YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright])
vmax = np.max(YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright])

# %%
bordersize = N // 2 - bigoffset // 4
clipsize = (bordersize + ((gridsize - 1) * offset) // 2)

plt.imshow(YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright], interpolation = 'none',
          cmap = 'jet')
vmin = np.min(YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright])
vmax = np.max(YY_I_test_full[0, clipleft: -clipright, clipleft: -clipright])

# %%
# offset 4
import matplotlib.pyplot as plt
plt.imshow(stitched[0], cmap = 'jet')

# %% [markdown]
# Position jitter

# %%
from importlib import reload
from ptycho import tf_helper as hh
reload(hh)
# Out:
# <module 'ptycho.tf_helper' from '/home/ollie/Documents/scratch/ptycho/notebooks/ptycho/tf_helper.py'>

# %%
# Testing new components
imgs_merged = hh.reassemble_patches_position(Y_I_test, coords_test)

channels_translated = hh.extract_patches_position(imgs_merged, coords_test)

assert np.isclose(
    hh.reassemble_patches_position(Y_I_test, coords_test),
    hh.reassemble_patches(Y_I_test)).all()

assert np.isclose(
    channels_translated,
    hh.extract_nested_patches(imgs_merged, fmt = 'flat')).all()

# %%
patches_g = hh.extract_nested_patches(YY_I_test_full)
patches_p = hh.extract_nested_patches_position(YY_I_test_full, coords_test)

assert np.isclose(patches_p, patches_g).all()

# %%
from ptycho import evaluation
