# %%
from importlib import reload
import matplotlib.pyplot as plt

def init():
    from ptycho import params as p
    p.cfg['positions.provided'] = False
    p.cfg['data_source'] = 'lines'
    p.cfg['set_phi'] = False
    p.cfg['nepochs'] = 60

    p.cfg['offset'] = 4
    p.cfg['max_position_jitter'] = 3
    p.cfg['output_prefix'] = 'lines3'

    p.cfg['gridsize'] = 2
    p.cfg['n_filters_scale'] = 2
    p.cfg['object.big'] = True
    p.cfg['intensity_scale.trainable'] = True
    p.cfg['probe.trainable'] = False
    
    p.cfg['outer_offset_train'] = 8
    p.cfg['outer_offset_test'] = 20
    p.cfg['nimgs_train'] = 2
    p.cfg['nimgs_test'] = 2
    
init()
from ptycho.evaluation import save_metrics
from ptycho.evaluation import trim
from ptycho import tf_helper as hh

from ptycho import params as p
from ptycho import generate_data as init
# Out:
# 2024-02-28 14:37:24.919932: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 14:37:24.919986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 14:37:24.949306: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-28 14:37:25.011823: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-28 14:37:25.751367: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-28 14:37:26.861808: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:26.966459: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:26.966660: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# /home/ollie/anaconda3/envs/py310_2/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2024-02-28 14:37:27.357135: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:27.357344: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:27.357495: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:27.426575: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:27.426756: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:27.426871: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2024-02-28 14:37:27.426994: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-28 14:37:27.427121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22379 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Loading result from disk cache.
# Loading result from disk cache.
# nphoton 8.962649
# 2024-02-28 14:37:34.329182: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 1.0000132

# %% [markdown]
# ## Full PINN model, best params:

# %%
from ptycho import params as p
p.cfg['data_source'] = 'lines'
p.cfg['offset'] = 4
p.cfg['max_position_jitter'] = 10
p.cfg['output_prefix'] = 'lines2'

p.cfg['gridsize'] = 2
p.cfg['n_filters_scale'] = 2
p.cfg['object.big'] = True
p.cfg['intensity_scale.trainable'] = True

from ptycho import train, model
# reload(model)
# reload(train)

# print(p.cfg)
from ptycho.train import *
# Out:
# input shape (None, 64, 64, 1)
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/py310_2/lib/python3.10/site-packages/tensorflow_probability/python/distributions/distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 64, 64, 4)]          0         []
#
#  tf.math.truediv (TFOpLambd  (None, 64, 64, 4)            0         ['input[0][0]']
#  a)
#
#  conv2d (Conv2D)             (None, 64, 64, 64)           2368      ['tf.math.truediv[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 64)           0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)          147584    ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 128)          0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 256)          590080    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 256)            0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)            590080    ['max_pooling2d_2[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 256)            590080    ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)            590080    ['conv2d_8[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 256)            590080    ['conv2d_14[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#  D)
#
#  up_sampling2d_2 (UpSamplin  (None, 16, 16, 256)          0         ['conv2d_15[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 128)          295040    ['up_sampling2d[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 128)          295040    ['up_sampling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)          147584    ['conv2d_10[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 128)          147584    ['conv2d_16[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 128)          0         ['conv2d_11[0][0]']
#  g2D)
#
#  up_sampling2d_3 (UpSamplin  (None, 32, 32, 128)          0         ['conv2d_17[0][0]']
#  g2D)
#
#  tf.__operators__.getitem (  (None, 32, 32, 124)          0         ['up_sampling2d_1[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (None, 32, 32, 124)          0         ['up_sampling2d_3[0][0]']
#   (SlicingOpLambda)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 1)            1117      ['tf.__operators__.getitem[0][
#                                                                     0]']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 4)            4468      ['tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
#  amp (Lambda)                (None, 32, 32, 1)            0         ['conv2d_6[0][0]']
#
#  phi (Lambda)                (None, 32, 32, 4)            0         ['conv2d_12[0][0]']
#
#  amp_padded (ZeroPadding2D)  (None, 64, 64, 1)            0         ['amp[0][0]']
#
#  phase_padded (ZeroPadding2  (None, 64, 64, 4)            0         ['phi[0][0]']
#  D)
#
#  obj (Lambda)                (None, 64, 64, 4)            0         ['amp_padded[0][0]',
#                                                                      'phase_padded[0][0]']
#
#  input_positions (InputLaye  [(None, 1, 2, 4)]            0         []
#  r)
#
#  padded_obj_2 (Lambda)       (None, 78, 78, 1)            0         ['obj[0][0]',
#                                                                      'input_positions[0][0]']
#
#  padded_objs_with_offsets (  (None, None, None, 1)        0         ['padded_obj_2[0][0]',
#  Lambda)                                                             'input_positions[0][0]']
#
#  probe_illumination (ProbeI  ((None, 64, 64, 1),          4096      ['padded_objs_with_offsets[0][
#  llumination)                 (1, 64, 64, 1))                       0]']
#
#  pred_amplitude (Lambda)     ((None, 64, 64, 1),          0         ['probe_illumination[0][0]']
#                               (None, 64, 64, 1))
#
#  pred_diff_channels (Lambda  (None, 64, 64, 4)            0         ['pred_amplitude[0][1]']
#  )
#
#  tf.math.multiply (TFOpLamb  (None, 64, 64, 4)            0         ['pred_diff_channels[0][0]']
#  da)
#
#  trimmed_obj (Lambda)        (None, 64, 64, 1)            0         ['padded_obj_2[0][0]']
#
#  distribution_lambda (Distr  ((None, 64, 64, 4),          0         ['tf.math.multiply[0][0]']
#  ibutionLambda)               (None, 64, 64, 4))
#
# ==================================================================================================
# Total params: 4401233 (16.80 MB)
# Trainable params: 4397137 (16.77 MB)
# Non-trainable params: 4096 (32.00 KB)
# __________________________________________________________________________________________________
# None
# using nominal scan positions for training
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2024-02-28 14:37:39.706232: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-02-28 14:37:39.706249: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-02-28 14:37:39.706271: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1883] Profiler found 1 GPUs
# 2024-02-28 14:37:39.706556: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:137] cuptiGetTimestamp: error 999:
# 2024-02-28 14:37:39.706565: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:186] cuptiSubscribe: ignored due to a previous error.
# 2024-02-28 14:37:39.706576: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-02-28 14:37:39.706580: E external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1935] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2024-02-28 14:37:39.706608: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-02-28 14:37:39.706616: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:142] cuptiFinalize: ignored due to a previous error.
# 2024-02-28 14:37:39.706619: E external/local_xla/xla/backends/profiler/gpu/cupti_error_manager.cc:459] cuptiGetResultString: ignored due to a previous error.
# 2024-02-28 14:37:39.706622: E external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:2026] function cupti_interface_->Finalize()failed with error
# Epoch 1/60
# input shape (None, 64, 64, 1)
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# input shape (None, 64, 64, 1)
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 2024-02-28 14:37:47.563131: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-02-28 14:37:47.724006: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-02-28 14:37:47.942493: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x55a8da293110
# 2024-02-28 14:37:49.445329: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fe7fcf29b90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-28 14:37:49.445349: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-02-28 14:37:49.452837: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709149069.526034    3853 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 799/799 [==============================] - ETA: 0s - loss: 77264152.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 12.7528 - distribution_lambda_loss: 77264152.0000input shape (None, 64, 64, 1)
# 799/799 [==============================] - 16s 13ms/step - loss: 77264152.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss:
1250 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.6073 - distribution_lambda_loss: 1535017.1250 - val_loss: 1763181.8750 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.7769 - val_distribution_lambda_loss: 1763181.8750 - lr: 1.0000e-04
# input shape (None, 64, 64, 1)
# 69/69 [==============================] - 4s 54ms/step
# subtracting mean -0.0109314835
# subtracting mean 0.0
# mean scale adjustment: 4.296053
# mean scale adjustment: 4.296053
# performed by index method
# performed by index method
# performed by index method
# mean scale adjustment: 1
# mean scale adjustment: 1

# %%
from ptycho import train_pinn

# %%
d = save_metrics(stitched_obj, YY_ground_truth, label = 'PINN,NLL,overlaps')
d
#d0 = d
# Out:
# subtracting mean -0.0109314835
# subtracting mean 0.0
# mean scale adjustment: 4.296053
# mean scale adjustment: 4.296053
# performed by index method
# performed by index method
# performed by index method
# mean scale adjustment: 1
# mean scale adjustment: 1
# {'mae': (0.04461262, 0.002502958),
#  'mse': (0.0037391568, 1.0237379e-05),
#  'psnr': (72.40306681542333, 98.02891623249826),
#  'frc50': (166, nan)}

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# reconstructed amplitude images
img1 = axs[0, 0].imshow(np.absolute(stitched_obj)[0], cmap='jet', interpolation='none')
axs[0, 0].set_title('Reconstructed amplitude')

# reconstructed phase images
axs[0, 1].imshow(np.angle(stitched_obj)[0], cmap='jet')
fig.colorbar(img1, ax=axs[0, 1])
axs[0, 1].set_title('Reconstructed phase')

# ground truth amplitude images
img = axs[1, 0].imshow(np.absolute(init.YY_ground_truth), interpolation='none', cmap='jet')
axs[1, 0].set_title('Ground truth amplitude')

# ground truth phase images
img = axs[1, 1].imshow(np.angle(init.YY_ground_truth), interpolation='none', cmap='jet')
axs[1, 1].set_title('Ground truth phase')
fig.colorbar(img, ax=axs[1, 1])

# %%
from ptycho import evaluation
idxs = list(range(0, 100, 10))
ptychopinn_heatmaps = [evaluation.summarize(i, pred_amp, reconstructed_obj,
                    X_test, Y_I_test, Y_phi_test, np.absolute(p.get('probe'))[:, :, 0], 0) for i in idxs]
# Out:
# phase min: -0.12547822 phase max: 0.103973426
# /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/ptychoPINN-0.0.0-py3.9.egg/ptycho/evaluation.py:80: RuntimeWarning: divide by zero encountered in log
#   true_diffraction = np.log(X_test)[i, :, :, channel]
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426
# phase min: -0.12547822 phase max: 0.103973426

# %%
from ptycho import evaluation

evaluation.plt_metrics(history, metric2 = 'trimmed_obj_loss')
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## PINN, NLL, no overlap:

# %%
from ptycho import train_pinn

# %%
p.cfg['gridsize'] = 1
p.cfg['nll_weight'] = 1.
p.cfg['mae_weight'] = 0.

reload(init)
reload(train.model)
reload(train_pinn)

# print(p.cfg)
from ptycho.generate_data import *
from ptycho.train import *;
# Out:
# Loading result from disk cache.
# No cached result found. Calculating and caching the result.
# simulating gaussian position jitter, scale 0.0
# Sampling on regular grid
# input shape (None, 64, 64, 1)
# 1.0000081
# nphoton 8.962428
# input shape (None, 64, 64, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 64, 64, 1)]  0           []
#
#  tf.math.truediv (TFOpLambda)   (None, 64, 64, 1)    0           ['input[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 64)   640         ['tf.math.truediv[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['max_pooling2d_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 256)    590080      ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_8[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_14[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 256)  0           ['conv2d_9[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 256)  0          ['conv2d_15[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['up_sampling2d[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 128)  295040      ['up_sampling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_10[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_16[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_11[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_17[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 32, 32, 124)  0          ['up_sampling2d_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 32, 32, 124)  0          ['up_sampling2d_3[0][0]']
#  icingOpLambda)
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 1)    1117        ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 1)    1117        ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  amp (Lambda)                   (None, 32, 32, 1)    0           ['conv2d_6[0][0]']
#
#  phi (Lambda)                   (None, 32, 32, 1)    0           ['conv2d_12[0][0]']
#
#  amp_padded (ZeroPadding2D)     (None, 64, 64, 1)    0           ['amp[0][0]']
#
#  phase_padded (ZeroPadding2D)   (None, 64, 64, 1)    0           ['phi[0][0]']
#
#  obj (Lambda)                   (None, 64, 64, 1)    0           ['amp_padded[0][0]',
#                                                                   'phase_padded[0][0]']
#
#  input_positions (InputLayer)   [(None, 1, 2, 1)]    0           []
#
#  padded_obj_2 (Lambda)          (None, 74, 74, 1)    0           ['obj[0][0]',
#                                                                   'input_positions[0][0]']
#
#  padded_objs_with_offsets (Lamb  (None, None, None,   0          ['padded_obj_2[0][0]',
#  da)                            1)                                'input_positions[0][0]']
#
#  probe_illumination (ProbeIllum  ((None, 64, 64, 1),  4096       ['padded_objs_with_offsets[0][0]'
#  ination)                        (1, 64, 64, 1))                 ]
#
#  pred_amplitude (Lambda)        ((None, 64, 64, 1),  0           ['probe_illumination[0][0]']
#                                  (None, 64, 64, 1))
#
#  pred_diff_channels (Lambda)    (None, 64, 64, 1)    0           ['pred_amplitude[0][1]']
#
#  tf.math.multiply (TFOpLambda)  (None, 64, 64, 1)    0           ['pred_diff_channels[0][0]']
#
#  trimmed_obj (Lambda)           (None, 64, 64, 1)    0           ['padded_obj_2[0][0]']
#
#  distribution_lambda (Distribut  ((None, 64, 64, 1),  0          ['tf.math.multiply[0][0]']
#  ionLambda)                      (None, 64, 64, 1))
#
# ==================================================================================================
# Total params: 4,396,154
# Trainable params: 4,392,058
# Non-trainable params: 4,096
# __________________________________________________________________________________________________
# None
# 2023-11-26 17:05:35.524149: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-11-26 17:05:35.524164: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# using nominal scan positions for training
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2023-11-26 17:05:35.831263: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2023-11-26 17:05:35.831366: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed
# Epoch 1/60
# input shape (None, 64, 64, 1)
# input shape (None, 64, 64, 1)
# 819/819 [==============================] - ETA: 0s - loss: 17710290.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 12.0527 - distribution_lambda_loss: 17710290.0000input shape (None, 64, 64, 1)
# 819/819 [==============================] - 10s 11ms/step - loss: 17710290.0000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 12.0527 - distribution_lambda_loss: 17710290.0000 - val_loss: 7750457.5000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 10.8537 - val_distribution_lambda_loss: 7750457.5000 - lr: 0.0010
# Epoch 2/60
# 819/819 [==============================] - 9s 11ms/step - loss: 5550239.5000 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 9.6786 - distribution_lambda_loss: 5550239.5000 - val_loss: 4134759.2500 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 9.1870 - val_distribution_lambda_loss: 4134759.2500 - lr: 0.0010
# Epoch 3/60
# 819/819 [==============================] - 9s 11ms/step - loss: 4120911.7500 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 8
- val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.4321 - val_distribution_lambda_loss: 373773.6875 - lr: 1.0000e-04
# Epoch 43/60
# 819/819 [==============================] - 9s 11ms/step - loss: 313038.7812 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.2818 - distribution_lambda_loss: 313038.7812 - val_loss: 403447.3750 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.5341 - val_distribution_lambda_loss: 403447.3750 - lr: 1.0000e-04
# Epoch 44/60
# 819/819 [==============================] - 9s 11ms/step - loss: 308431.1875 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.2594 - distribution_lambda_loss: 308431.1875 - val_loss: 358350.5625 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.4141 - val_distribution_lambda_loss: 358350.5625 - lr: 1.0000e-04
# Epoch 45/60
# 819/819 [==============================] - 9s 11ms/step - loss: 306934.4062 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.2501 - distribution_lambda_loss: 306934.4062 - val_loss: 379604.6875 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.4647 - val_distribution_lambda_loss: 379604.6875 - lr: 1.0000e-04
# Epoch 46/60
# 819/819 [==============================] - 9s 11ms/step - loss: 304947.4375 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.2386 - distribution_lambda_loss: 304947.4375 - val_loss: 351193.9062 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.3474 - val_distribution_lambda_loss: 351193.9062 - lr: 1.0000e-04
# Epoch 47/60
# 819/819 [==============================] - 9s 11ms/step - loss: 300049.0625 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.2150 - distribution_lambda_loss: 300049.0625 - val_loss: 360058.5625 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.4189 - val_distribution_lambda_loss: 360058.5625 - lr: 1.0000e-04
# Epoch 48/60
# 819/819 [==============================] - 9s 11ms/step - loss: 298666.4375 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.2065 - distribution_lambda_loss: 298666.4375 - val_loss: 359888.2500 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.4015 - val_distribution_lambda_loss: 359888.2500 - lr: 1.0000e-04
# Epoch 49/60
# 819/819 [==============================] - 9s 11ms/step - loss: 274926.6875 - trimmed_obj_loss: 0.0000e+00 - tf.math.multiply_loss: 3.0689 - distribution_lambda_loss: 274926.6875 - val_loss: 336044.5000 - val_trimmed_obj_loss: 0.0000e+00 - val_tf.math.multiply_loss: 3.2931 - val_distribution_lambda_loss: 336044.5000 - lr: 1.0000e-04
# input shape (None, 64, 64, 1)
# 69/69 [==============================] - 2s 22ms/step

# %%
from ptycho.generate_data import *
X_test.shape
# Out:
# TensorShape([2178, 64, 64, 1])

# %%
from ptycho import evaluation
pinn_heatmaps = [evaluation.summarize(i, train_pinn.pred_amp, train_pinn.reconstructed_obj,
                    X_test, Y_I_test, Y_phi_test, np.absolute(p.get('probe'))[:, :, 0], 0) for i in idxs]
# Out:
# phase min: -3.0122302 phase max: 0.3156401
# /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/ptychoPINN-0.0.0-py3.9.egg/ptycho/evaluation.py:80: RuntimeWarning: divide by zero encountered in log
#   true_diffraction = np.log(X_test)[i, :, :, channel]
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# phase min: -3.0122302 phase max: 0.3156401
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# phase min: -3.0122302 phase max: 0.3156401

# %%
img_dict_ptychopinn = ptychopinn_heatmaps[0]
img_dict_pinn = pinn_heatmaps[0]

img_dict_pinn.keys()
# Out:
# dict_keys(['true_amp_illuminated', 'rec_amp_illuminated', 'true_phase', 'true_amp_full', 'rec_amp_full', 'rec_phase', 'true_diffraction', 'rec_diffraction'])

# %% [markdown]
# # Compare reconstructions of PINN with and without overlaps

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.size'] = 10

fig, axs = plt.subplots(2, 3, figsize=(7.5, 5))

# Slicing for central 32x32 region
slice_32x32 = slice(img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 - 16, 
                    img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 + 16)

# Top row for diffraction
axs[0, 0].imshow(img_dict_ptychopinn['true_diffraction'], cmap='jet')
axs[0, 0].set_title('True diffraction')
axs[0, 0].axis('off')

axs[0, 1].imshow(img_dict_ptychopinn['rec_diffraction'], cmap='jet')
axs[0, 1].set_title('PtychoPINN: \n reconstructed diffraction')
axs[0, 1].axis('off')

axs[0, 2].imshow(img_dict_pinn['rec_diffraction'], cmap='jet')
axs[0, 2].set_title('PINN: \n reconstructed diffraction')
axs[0, 2].axis('off')

# Bottom row for amplitude
axs[1, 0].imshow(img_dict_ptychopinn['true_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 0].set_title('True amplitude')
axs[1, 0].axis('off')

axs[1, 1].imshow(img_dict_ptychopinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 1].set_title('PtychoPINN: \n reconstructed amplitude')
axs[1, 1].axis('off')

axs[1, 2].imshow(img_dict_pinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 2].set_title('PINN: \n reconstructed amplitude')
axs[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from matplotlib import rcParams

matplotlib.rcParams['font.size'] = 11
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Computer Modern']

fig, axs = plt.subplots(2, 3, figsize=(7.5, 5))

# Slicing for central 32x32 region
slice_32x32 = slice(img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 - 16, 
                    img_dict_ptychopinn['true_amp_illuminated'].shape[0]//2 + 16)

# Save true_diffraction as a variable for easier subtraction
true_diffraction = img_dict_ptychopinn['true_diffraction']

# Calculate difference for PtychoPINN and PINN

diff_ptychopinn = np.log(
    np.abs(np.exp(img_dict_ptychopinn['rec_diffraction']) - np.exp(true_diffraction) * intensity_scale)
)
diff_pinn = np.log(
    np.abs(np.exp(img_dict_pinn['rec_diffraction']) - np.exp(true_diffraction) * intensity_scale)
)

# Calculate vmin and vmax (use highest non-infinite value if vmax is np.inf)
vmin = 0#np.minimum(np.min(diff_ptychopinn), np.min(diff_pinn))

# Replace np.inf with a large finite number for max
max_ptychopinn = np.max(diff_ptychopinn[np.isfinite(diff_ptychopinn)]) if np.isinf(np.max(diff_ptychopinn)) else np.max(diff_ptychopinn)
max_pinn = np.max(diff_pinn[np.isfinite(diff_pinn)]) if np.isinf(np.max(diff_pinn)) else np.max(diff_pinn)
vmax = np.maximum(max_ptychopinn, max_pinn)

# Top row for diffraction
im1 = axs[0, 0].imshow(true_diffraction + np.log(intensity_scale), cmap='jet')
axs[0, 0].set_title('True diffraction \n (log)')
axs[0, 0].axis('off')
fig.colorbar(im1, ax=axs[0, 0])

im2 = axs[0, 1].imshow(diff_ptychopinn, cmap='jet', vmin=vmin, vmax=vmax)
axs[0, 1].set_title('PtychoPINN: diffraction \n error (log absolute)')
axs[0, 1].axis('off')
fig.colorbar(im2, ax=axs[0, 1])

im3 = axs[0, 2].imshow(diff_pinn, cmap='jet', vmin=vmin, vmax=vmax)
axs[0, 2].set_title('PINN: diffraction \n error (log absolute)')
axs[0, 2].axis('off')
fig.colorbar(im3, ax=axs[0, 2])

# Bottom row for amplitude
axs[1, 0].imshow(img_dict_ptychopinn['true_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 0].set_title('True amplitude')
axs[1, 0].axis('off')

axs[1, 1].imshow(img_dict_ptychopinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 1].set_title('PtychoPINN: \n reconstructed amplitude')
axs[1, 1].axis('off')

axs[1, 2].imshow(img_dict_pinn['rec_amp_illuminated'][slice_32x32, slice_32x32], cmap='jet')
axs[1, 2].set_title('PINN: \n reconstructed amplitude')
axs[1, 2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern

# %%
def normed_ff_np(arr):
    return (f.fftshift(np.absolute(f.fft2(np.array(arr)))) / np.sqrt(h * w))

# %%
from ptycho import fourier as f

# %% [markdown]
# # More real- and diffraction-space reconstructions

# %%
# !ln ../xrd_clustering/notebooks/visualization.py
from ptycho import visualization as vis
reload(vis)

off = 5
i = 0

vmin = np.min(Y_I_test[:, 16:-16, 16:-16][i:i + off])
vmax = np.max(Y_I_test[:, 16:-16, 16:-16][i:i + off])

print('diffraction reconstruction')
vis.display_imgs(np.log(np.absolute(pred_amp[:, :, :, 0]))[i:i + off])

print('diffraction ground truth')
vis.display_imgs(np.log(np.absolute(X_test[:, :, :, 0]))[i:i + off])

print('object reconstruction (amp)')
vis.display_imgs(np.absolute(reconstructed_obj[:, 16:-16, 16:-16, 0])[i:i + off], vmin = vmin, vmax = vmax)
# print('object reconstruction (phase)')
# vis.display_imgs(np.angle(b[:, 16:-16, 16:-16, 0])[i:i + 10])#, vmin = vmin, vmax = vmax)
print('object ground truth')
vis.display_imgs(Y_I_test[:, 16:-16, 16:-16, 0][i:i + off], vmin = vmin, vmax = vmax)
# Out:
# diffraction reconstruction
# diffraction ground truth
# /tmp/ipykernel_567633/2933227620.py:15: RuntimeWarning: divide by zero encountered in log
#   vis.display_imgs(np.log(np.absolute(X_test[:, :, :, 0]))[i:i + off])
# object reconstruction (amp)
# object ground truth

# %%
plt.rcParams["figure.figsize"] = (10, 5)


plt.subplot(2, 3, 1)

plt.imshow(Y_I_train[0, :, :, 0], cmap = 'jet')

plt.subplot(2, 3, 2)
plt.imshow(np.absolute(model.autoencoder.variables[-1]), cmap = 'jet')
# plt.colorbar()


plt.subplot(2, 3, 4)
plt.imshow(np.absolute(reconstructed_obj[100, :, :, 0]), cmap = 'jet')

plt.subplot(2, 3, 5)
tmp = np.absolute(f.fftshift(f.fft2(np.array(model.autoencoder.variables[-1][:, :, 0]))))
plt.imshow(np.log(tmp),
          cmap  ='jet')

plt.subplot(2, 3, 6)
plt.imshow(np.log(X_train[0, :, :, 0]), cmap = 'jet')

# for i, v in enumerate(model.autoencoder.variables):
#     print(i, v.shape)
# Out:
# /tmp/ipykernel_567633/266772117.py:18: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(tmp),
# /tmp/ipykernel_567633/266772117.py:22: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(X_train[0, :, :, 0]), cmap = 'jet')

# %%
plt.rcParams["figure.figsize"] = (5, 5)
Itest = (X_test * p.get('intensity_scale'))**2
print(Itest.shape, np.max(Itest, axis = 1).max(axis = 1).mean())

plt.imshow(np.log(np.sqrt(Itest[0, :, :, 0])), cmap = 'jet')
plt.colorbar()
# Out:
# (2178, 64, 64, 1) 102344860.0
# /tmp/ipykernel_567633/1530809169.py:5: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(np.sqrt(Itest[0, :, :, 0])), cmap = 'jet')
