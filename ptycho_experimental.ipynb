# %% [markdown]
# ### This model uses the diffraction from overlapping sample regions to solve the inversion symmetry problem and improve reconstruction quality

# %% [markdown]
# misc notes:
#
# clearing gpu memory: `for i in $(sudo lsof /dev/nvidia0 | grep python | awk '{print $2}' | sort -u); do sudo kill -9 $i; done`
# https://github.com/tensorflow/tensorflow/issues/36465

# %%
# %matplotlib inline

import os
from ptycho import tf_helper as hh
from ptycho import fourier as f
from ptycho import datasets
from ptycho.params import cfg
from ptycho.params import params

from sklearn.utils import shuffle

from importlib import reload
import os

import tensorflow as tf

import tensorflow_addons as tfa

import importlib
import matplotlib.pyplot as plt
import matplotlib

import numpy as np
# from tqdm.notebook import tqdm as tqdm

from tensorflow.keras.layers import Layer
from math import pi
from tensorflow.keras import backend as K

matplotlib.rcParams['font.size'] = 12
# Out:
# 2022-11-14 16:50:49.319900: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-14 16:50:49.405917: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-14 16:50:49.753015: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/ollie/anaconda3/envs/tf/lib/
# 2022-11-14 16:50:49.753061: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/ollie/anaconda3/envs/tf/lib/
# 2022-11-14 16:50:49.753066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2022-11-14 16:50:50.258357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:50.276300: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:50.276440: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# 2022-11-14 16:50:51.153843: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-14 16:50:51.154615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:51.154793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:51.154903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:51.500640: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:51.500771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:51.500863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-14 16:50:51.500933: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2022-11-14 16:50:51.501005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20102 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6

# %%
# !nvidia-smi
# Out:
# /bin/bash: /home/ollie/anaconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Mon Nov 14 16:50:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.65.01    Driver Version: 515.65.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:04:00.0 Off |                  N/A |
# |  0%   51C    P2   126W / 420W |   2660MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4474      G   /usr/lib/xorg/Xorg                148MiB |
# |    0   N/A  N/A      4610      G   /usr/bin/gnome-shell               10MiB |
# |    0   N/A  N/A      4933      G   ...bexec/gnome-initial-setup        4MiB |
# |    0   N/A  N/A    442714      C   ...conda3/envs/tf/bin/python     2029MiB |
# |    0   N/A  N/A    671127      C   ...conda3/envs/tf/bin/python      463MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Some training and probe parameters

# %%
h = w = N = cfg['N'] = 64
# offset between neighboring scan points, in pixels
offset = cfg['offset'] = 4
gridsize = cfg['gridsize'] = 2

nepochs=20
#wt_path = 'wts4' #Where to store network weights
# wt_path = 'wts4.1'
batch_size = cfg['batch_size'] = 16

filt = f.lowpass_g(.55, np.ones(N), sym = True)
#filt = f.lowpass_g(.7, np.ones(N), sym = True)

# TODO assert symmetry
probe = f.gf(((np.einsum('i,j->ij', filt, filt)) > .5).astype(float), 1) + 1e-9
probe_small = probe[16:-16, 16:-16]
tprobe = (tf.convert_to_tensor(probe, tf.float32)[..., None])
cfg['probe'] = tprobe
tprobe_small = (tf.convert_to_tensor(probe_small, tf.float32)[..., None])

# if (not os.path.isdir(path+wt_path)):
#     os.mkdir(wt_path)

plt.imshow(tprobe_small, cmap = 'jet')

# %% [markdown]
# ### Load experimental dataset

# %%
#from ptycho.experimental import *
from ptycho import experimental
# Out:
#   0%|          | 0/161 [00:00<?, ?it/s]
# 101
# (16100, 64, 64, 1) (3600, 64, 64, 1)
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: calling extract_image_patches (from tensorflow.python.ops.array_ops) with ksizes is deprecated and will be removed in a future version.
# Instructions for updating:
# ksizes is deprecated, use sizes instead
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: calling extract_image_patches (from tensorflow.python.ops.array_ops) with ksizes is deprecated and will be removed in a future version.
# Instructions for updating:
# ksizes is deprecated, use sizes instead

# %% [markdown]
# ### Simulate ptychography data

# %%
plt.imshow(experimental.inverted_patches_I[0, :, :, 0], cmap = 'jet')
#plt.imshow(inverted_patches_phi[0, :, :, 0], cmap = 'jet')

cfg['bigoffset'] = 4
X_train, Y_I_train, Y_phi_train, intensity_scale, _Y_I_train_full, _ = datasets.mk_expdata('train', probe)
cfg['intensity_scale'] = intensity_scale

cfg['bigoffset'] = ((gridsize - 1) * offset + N // 2)# // 2
bigN = N + (gridsize - 1) * offset
X_test, Y_I_test, Y_phi_test, _, _Y_I_test_full, norm_Y_I_test = datasets.mk_expdata('test', probe, intensity_scale)

# TODO shuffle should be after flatten
X_train, Y_I_train, Y_phi_train = shuffle(X_train.numpy(), Y_I_train.numpy(), Y_phi_train.numpy(), random_state=0)

(Y_I_test).shape, Y_I_train.shape
# Out:
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow_probability-0.18.0-py3.9.egg/tensorflow_probability/python/distributions/distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# WARNING:tensorflow:From /home/ollie/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow_probability-0.18.0-py3.9.egg/tensorflow_probability/python/distributions/distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# (TensorShape([121, 64, 64, 4]), TensorShape([10609, 64, 64, 4]))

# %%
plt.imshow(_Y_I_train_full[0], cmap = 'jet')

# %%
print('intensity scale:', intensity_scale, '\n',
      'max photon count:', (np.max(Y_I_train, axis = (1, 2, 3)).mean() * intensity_scale)**2, '\n',
      'shapes:', (Y_phi_test).shape, (Y_I_test).shape, Y_I_train.shape)
# Out:
# intensity scale: 1698.6838
#  max photon count: 2561901.524849072
#  shapes: (121, 64, 64, 4) (121, 64, 64, 4) (10609, 64, 64, 4)

# %%
plt.imshow(Y_I_train[0, :, :, 0], cmap = 'jet')

# %% [markdown]
# ### Norm conservation consistency check:

# %%
print(np.linalg.norm(X_train[0]) /  np.linalg.norm(Y_I_train[0]))

def normed_ff_np(arr):
    return (f.fftshift(np.absolute(f.fft2(np.array(arr)))) / np.sqrt(h * w))
# Out:
# 0.9999978

# %% [markdown]
# ### Inversion symmetry check:

# %%
assert np.isclose(normed_ff_np(Y_I_train[0, :, :, 0]),
            tf.math.conj(normed_ff_np(Y_I_train[0, ::-1, ::-1, 0])), atol = 1e-6).all()

#normed_ff_np(Y_I_train[0, :, :, 0]).sum() / normed_ff_np(Y_I_train[0, :, :, 0]).sum()

# %% [markdown]
# ### np / tf consistency check:

# %%
plt.imshow(Y_I_train[0, :, :, 0])

# %% [markdown]
# ### Number of photons consitency check

# %%
np.log10(np.sum((X_train[:, :, :] * intensity_scale)**2, axis = (1, 2))).mean()
# Out:
# 8.997815

# %%
i = 1

plt.imshow(np.log(normed_ff_np
                  (np.array(hh.combine_complex(Y_I_train, Y_phi_train))[0, :, :, 0])), cmap = 'jet')
plt.colorbar()

# %%
plt.imshow(np.log(X_train[0, :, :, 0]), cmap = 'jet')
plt.colorbar()
# Out:
# /tmp/ipykernel_671127/1841061669.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(X_train[0, :, :, 0]), cmap = 'jet')

# %% [markdown]
# ## Define the network structure

# %%
plt.rcParams["figure.figsize"] = (10, 10)

# %%
from ptycho import model
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 64, 64, 4)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   1184        ['input[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 128)    147584      ['max_pooling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 128)    147584      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 128)    147584      ['conv2d_6[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 128)    147584      ['conv2d_11[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 128)  0           ['conv2d_7[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 128)  0          ['conv2d_12[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 64)   73792       ['up_sampling2d[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 64)   73792       ['up_sampling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   36928       ['conv2d_8[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_13[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)  0           ['conv2d_9[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 64)  0           ['conv2d_14[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 1)    577         ['up_sampling2d_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 1)    577         ['up_sampling2d_3[0][0]']
#
#  amp (Lambda)                   (None, 32, 32, 1)    0           ['conv2d_10[0][0]']
#
#  phi (Lambda)                   (None, 32, 32, 1)    0           ['conv2d_15[0][0]']
#
#  obj (Lambda)                   (None, 32, 32, 1)    0           ['amp[0][0]',
#                                                                   'phi[0][0]']
#
#  padded_obj (ZeroPadding2D)     (None, 64, 64, 1)    0           ['obj[0][0]']
#
#  padded_obj_2 (ZeroPadding2D)   (None, 68, 68, 1)    0           ['padded_obj[0][0]']
#
#  padded_objs_with_offsets (Lamb  (None, 64, 64, 1)   0           ['padded_obj_2[0][0]']
#  da)
#
#  padded_objs_with_offsets_illum  (None, 64, 64, 1)   0           ['padded_objs_with_offsets[0][0]'
#  inated (Lambda)                                                 ]
#
#  lambda (Lambda)                (None, 64, 64)       0           ['padded_objs_with_offsets_illumi
#                                                                  nated[0][0]']
#
#  lambda_1 (Lambda)              (None, 64, 64)       0           ['lambda[0][0]']
#
#  pred_amplitude (Lambda)        (None, 64, 64, 1)    0           ['lambda_1[0][0]']
#
#  pred_diff_channels (Lambda)    (None, 64, 64, 4)    0           ['pred_amplitude[0][0]']
#
#  distribution_lambda (Distribut  ((None, 64, 64, 4),  0          ['pred_diff_channels[0][0]']
#  ionLambda)                      (None, 64, 64, 4))
#
# ==================================================================================================
# Total params: 1,100,226
# Trainable params: 1,100,226
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
history = model.train(20, X_train, Y_I_train)
b, a, reg, L2_error = model.autoencoder.predict([X_test])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7fb4c97a5940> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7fb4c97a5940>: no matching AST found among candidates:
# # coding=utf-8
# lambda x: sigmoid(x)
# # coding=utf-8
# lambda x: math.pi * tanh(x)
# # coding=utf-8
# lambda x: hh.combine_complex(x[0], x[1])
# # coding=utf-8
# lambda x: hh.flatten_overlaps(x, fmt='flat')
# # coding=utf-8
# lambda x: tf.cast(tprobe, tf.complex64) * x
# # coding=utf-8
# lambda x: hh._flat_to_channel(x)
# # coding=utf-8
# lambda t: tfd.Independent(tfd.Poisson((t * intensity_scale) ** 2))
# # coding=utf-8
# lambda x, rv_x: -rv_x.log_prob(x)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7fb4c97a5940> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7fb4c97a5940>: no matching AST found among candidates:
# # coding=utf-8
# lambda x: sigmoid(x)
# # coding=utf-8
# lambda x: math.pi * tanh(x)
# # coding=utf-8
# lambda x: hh.combine_complex(x[0], x[1])
# # coding=utf-8
# lambda x: hh.flatten_overlaps(x, fmt='flat')
# # coding=utf-8
# lambda x: tf.cast(tprobe, tf.complex64) * x
# # coding=utf-8
# lambda x: hh._flat_to_channel(x)
# # coding=utf-8
# lambda t: tfd.Independent(tfd.Poisson((t * intensity_scale) ** 2))
# # coding=utf-8
# lambda x, rv_x: -rv_x.log_prob(x)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7fb4c97a5940> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7fb4c97a5940>: no matching AST found among candidates:
# # coding=utf-8
# lambda x: sigmoid(x)
# # coding=utf-8
# lambda x: math.pi * tanh(x)
# # coding=utf-8
# lambda x: hh.combine_complex(x[0], x[1])
# # coding=utf-8
# lambda x: hh.flatten_overlaps(x, fmt='flat')
# # coding=utf-8
# lambda x: tf.cast(tprobe, tf.complex64) * x
# # coding=utf-8
# lambda x: hh._flat_to_channel(x)
# # coding=utf-8
# lambda t: tfd.Independent(tfd.Poisson((t * intensity_scale) ** 2))
# # coding=utf-8
# lambda x, rv_x: -rv_x.log_prob(x)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2022-11-14 17:11:13.440244: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 630/630 [==============================] - ETA: 0s - loss: 548719488.0000 - padded_obj_loss: 0.1658 - pred_diff_channels_loss: 0.0218 - distribution_lambda_loss: 548719488.0000 - pred_diff_channels_1_loss: 0.0786
# Epoch 1: val_loss improved from inf to 347304416.00000, saving model to wts4.1/weights.01.h5
# 630/630 [==============================] - 11s 14ms/step - loss: 548719488.0000 - padded_obj_loss: 0.1658 - pred_diff_channels_loss: 0.0218 - distribution_lambda_loss: 548719488.0000 - pred_diff_channels_1_loss: 0.0786 - val_loss: 347304416.0000 - val_padded_obj_loss: 0.1697 - val_pred_diff_channels_loss: 0.0197 - val_distribution_lambda_loss: 347304416.0000 - val_pred_diff_channels_1_loss: 0.0810 - lr: 0.0010
# Epoch 2/20
# 630/630 [==============================] - ETA: 0s - loss: 316170592.0000 - padded_obj_loss: 0.1808 - pred_diff_channels_loss: 0.0183 - distribution_lambda_loss: 316170592.0000 - pred_diff_channels_1_loss: 0.0809
# Epoch 2: val_loss improved from 347304416.00000 to 298340096.00000, saving model to wts4.1/weights.02.h5
# 630/630 [==============================] - 8s 13ms/step - loss: 316170592.0000 - padded_obj_loss: 0.1808 - pred_diff_channels_loss: 0.0183 - distribution_lambda_loss: 316170592.0000 - pred_diff_channels_1_loss: 0.0809 - val_loss: 298340096.0000 - val_padded_obj_loss: 0.1738 - val_pred_diff_channels_loss: 0.0175 - val_distribution_lambda_loss: 298340096.0000 - val_pred_diff_channels_1_loss: 0.0803 - lr: 0.0010
# Epoch 3/20
# 628/630 [============================>.] - ETA: 0s - loss: 278923104.0000 - padded_obj_loss: 0.1946 - pred_diff_channels_loss: 0.0173 - distribution_lambda_loss: 278923104.0000 - pred_diff_channels_1_loss: 0.0824
# Epoch 3: val_loss improved from 298340096.00000 to 210269968.00000, saving model to wts4.1/weights.03.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 278611328.0000 - padded_obj_loss: 0.1946 - pred_diff_channels_loss: 0.0173 - distribution_lambda_loss: 278611328.0000 - pred_diff_channels_1_loss: 0.0824 - val_loss: 210269968.0000 - val_padded_obj_loss: 0.2029 - val_pred_diff_channels_loss: 0.0165 - val_distribution_lambda_loss: 210269968.0000 - val_pred_diff_channels_1_loss: 0.0840 - lr: 0.0010
# Epoch 4/20
# 629/630 [============================>.] - ETA: 0s - loss: 121812736.0000 - padded_obj_loss: 0.1996 - pred_diff_channels_loss: 0.0143 - distribution_lambda_loss: 121812736.0000 - pred_diff_channels_1_loss: 0.0839
# Epoch 4: val_loss improved from 210269968.00000 to 93378480.00000, saving model to wts4.1/weights.04.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 121758032.0000 - padded_obj_loss: 0.1996 - pred_diff_channels_loss: 0.0143 - distribution_lambda_loss: 121758032.0000 - pred_diff_channels_1_loss: 0.0839 - val_loss: 93378480.0000 - val_padded_obj_loss: 0.2011 - val_pred_diff_channels_loss: 0.0134 - val_distribution_lambda_loss: 93378480.0000 - val_pred_diff_channels_1_loss: 0.0828 - lr: 0.0010
# Epoch 5/20
# 627/630 [============================>.] - ETA: 0s - loss: 79586680.0000 - padded_obj_loss: 0.2104 - pred_diff_channels_loss: 0.0129 - distribution_lambda_loss: 79586680.0000 - pred_diff_channels_1_loss: 0.0838
# Epoch 5: val_loss improved from 93378480.00000 to 72632656.00000, saving model to wts4.1/weights.05.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 79537152.0000 - padded_obj_loss: 0.2104 - pred_diff_channels_loss: 0.0129 - distribution_lambda_loss: 79537152.0000 - pred_diff_channels_1_loss: 0.0838 - val_loss: 72632656.0000 - val_padded_obj_loss: 0.2163 - val_pred_diff_channels_loss: 0.0125 - val_distribution_lambda_loss: 72632656.0000 - val_pred_diff_channels_1_loss: 0.0847 - lr: 0.0010
# Epoch 6/20
# 626/630 [============================>.] - ETA: 0s - loss: 67892216.0000 - padded_obj_loss: 0.2168 - pred_diff_channels_loss: 0.0124 - distribution_lambda_loss: 67892216.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 6: val_loss improved from 72632656.00000 to 66306556.00000, saving model to wts4.1/weights.06.h5
# 630/630 [==============================] - 8s 13ms/step - loss: 67855528.0000 - padded_obj_loss: 0.2168 - pred_diff_channels_loss: 0.0124 - distribution_lambda_loss: 67855528.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 66306556.0000 - val_padded_obj_loss: 0.2188 - val_pred_diff_channels_loss: 0.0124 - val_distribution_lambda_loss: 66306556.0000 - val_pred_diff_channels_1_loss: 0.0850 - lr: 0.0010
# Epoch 7/20
# 627/630 [============================>.] - ETA: 0s - loss: 61489668.0000 - padded_obj_loss: 0.2227 - pred_diff_channels_loss: 0.0120 - distribution_lambda_loss: 61489668.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 7: val_loss improved from 66306556.00000 to 59936204.00000, saving model to wts4.1/weights.07.h5
# 630/630 [==============================] - 8s 13ms/step - loss: 61471708.0000 - padded_obj_loss: 0.2227 - pred_diff_channels_loss: 0.0120 - distribution_lambda_loss: 61471708.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 59936204.0000 - val_padded_obj_loss: 0.2235 - val_pred_diff_channels_loss: 0.0119 - val_distribution_lambda_loss: 59936204.0000 - val_pred_diff_channels_1_loss: 0.0839 - lr: 0.0010
# Epoch 8/20
# 630/630 [==============================] - ETA: 0s - loss: 56927148.0000 - padded_obj_loss: 0.2293 - pred_diff_channels_loss: 0.0118 - distribution_lambda_loss: 56927148.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 8: val_loss did not improve from 59936204.00000
# 630/630 [==============================] - 7s 12ms/step - loss: 56927148.0000 - padded_obj_loss: 0.2293 - pred_diff_channels_loss: 0.0118 - distribution_lambda_loss: 56927148.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 60843468.0000 - val_padded_obj_loss: 0.2280 - val_pred_diff_channels_loss: 0.0123 - val_distribution_lambda_loss: 60843468.0000 - val_pred_diff_channels_1_loss: 0.0826 - lr: 0.0010
# Epoch 9/20
# 627/630 [============================>.] - ETA: 0s - loss: 54517384.0000 - padded_obj_loss: 0.2365 - pred_diff_channels_loss: 0.0116 - distribution_lambda_loss: 54517384.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 9: val_loss improved from 59936204.00000 to 52971624.00000, saving model to wts4.1/weights.09.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 54527380.0000 - padded_obj_loss: 0.2365 - pred_diff_channels_loss: 0.0116 - distribution_lambda_loss: 54527380.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 52971624.0000 - val_padded_obj_loss: 0.2343 - val_pred_diff_channels_loss: 0.0116 - val_distribution_lambda_loss: 52971624.0000 - val_pred_diff_channels_1_loss: 0.0812 - lr: 0.0010
# Epoch 10/20
# 626/630 [============================>.] - ETA: 0s - loss: 50625588.0000 - padded_obj_loss: 0.2422 - pred_diff_channels_loss: 0.0114 - distribution_lambda_loss: 50625588.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 10: val_loss did not improve from 52971624.00000
# 630/630 [==============================] - 8s 12ms/step - loss: 50559992.0000 - padded_obj_loss: 0.2423 - pred_diff_channels_loss: 0.0114 - distribution_lambda_loss: 50559992.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 53613028.0000 - val_padded_obj_loss: 0.2433 - val_pred_diff_channels_loss: 0.0116 - val_distribution_lambda_loss: 53613028.0000 - val_pred_diff_channels_1_loss: 0.0831 - lr: 0.0010
# Epoch 11/20
# 628/630 [============================>.] - ETA: 0s - loss: 49455600.0000 - padded_obj_loss: 0.2487 - pred_diff_channels_loss: 0.0114 - distribution_lambda_loss: 49455600.0000 - pred_diff_channels_1_loss: 0.0838
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_loss did not improve from 52971624.00000
# 630/630 [==============================] - 8s 12ms/step - loss: 49481076.0000 - padded_obj_loss: 0.2486 - pred_diff_channels_loss: 0.0114 - distribution_lambda_loss: 49481076.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 54424924.0000 - val_padded_obj_loss: 0.2481 - val_pred_diff_channels_loss: 0.0119 - val_distribution_lambda_loss: 54424924.0000 - val_pred_diff_channels_1_loss: 0.0811 - lr: 0.0010
# Epoch 12/20
# 627/630 [============================>.] - ETA: 0s - loss: 37443208.0000 - padded_obj_loss: 0.2528 - pred_diff_channels_loss: 0.0106 - distribution_lambda_loss: 37443208.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 12: val_loss improved from 52971624.00000 to 38670148.00000, saving model to wts4.1/weights.12.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 37436540.0000 - padded_obj_loss: 0.2528 - pred_diff_channels_loss: 0.0106 - distribution_lambda_loss: 37436540.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 38670148.0000 - val_padded_obj_loss: 0.2500 - val_pred_diff_channels_loss: 0.0107 - val_distribution_lambda_loss: 38670148.0000 - val_pred_diff_channels_1_loss: 0.0822 - lr: 5.0000e-04
# Epoch 13/20
# 627/630 [============================>.] - ETA: 0s - loss: 34755928.0000 - padded_obj_loss: 0.2538 - pred_diff_channels_loss: 0.0104 - distribution_lambda_loss: 34755928.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 13: val_loss did not improve from 38670148.00000
# 630/630 [==============================] - 8s 12ms/step - loss: 34748448.0000 - padded_obj_loss: 0.2538 - pred_diff_channels_loss: 0.0104 - distribution_lambda_loss: 34748448.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 38837132.0000 - val_padded_obj_loss: 0.2505 - val_pred_diff_channels_loss: 0.0107 - val_distribution_lambda_loss: 38837132.0000 - val_pred_diff_channels_1_loss: 0.0819 - lr: 5.0000e-04
# Epoch 14/20
# 627/630 [============================>.] - ETA: 0s - loss: 33623668.0000 - padded_obj_loss: 0.2550 - pred_diff_channels_loss: 0.0103 - distribution_lambda_loss: 33623668.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 14: val_loss improved from 38670148.00000 to 36595852.00000, saving model to wts4.1/weights.14.h5
# 630/630 [==============================] - 8s 13ms/step - loss: 33641104.0000 - padded_obj_loss: 0.2549 - pred_diff_channels_loss: 0.0103 - distribution_lambda_loss: 33641104.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 36595852.0000 - val_padded_obj_loss: 0.2525 - val_pred_diff_channels_loss: 0.0106 - val_distribution_lambda_loss: 36595852.0000 - val_pred_diff_channels_1_loss: 0.0832 - lr: 5.0000e-04
# Epoch 15/20
# 628/630 [============================>.] - ETA: 0s - loss: 33231370.0000 - padded_obj_loss: 0.2563 - pred_diff_channels_loss: 0.0103 - distribution_lambda_loss: 33231370.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 15: val_loss did not improve from 36595852.00000
# 630/630 [==============================] - 8s 12ms/step - loss: 33237842.0000 - padded_obj_loss: 0.2563 - pred_diff_channels_loss: 0.0103 - distribution_lambda_loss: 33237842.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 36781332.0000 - val_padded_obj_loss: 0.2553 - val_pred_diff_channels_loss: 0.0105 - val_distribution_lambda_loss: 36781332.0000 - val_pred_diff_channels_1_loss: 0.0825 - lr: 5.0000e-04
# Epoch 16/20
# 626/630 [============================>.] - ETA: 0s - loss: 32436462.0000 - padded_obj_loss: 0.2581 - pred_diff_channels_loss: 0.0102 - distribution_lambda_loss: 32436462.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 16: val_loss improved from 36595852.00000 to 35793884.00000, saving model to wts4.1/weights.16.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 32444112.0000 - padded_obj_loss: 0.2581 - pred_diff_channels_loss: 0.0102 - distribution_lambda_loss: 32444112.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 35793884.0000 - val_padded_obj_loss: 0.2548 - val_pred_diff_channels_loss: 0.0103 - val_distribution_lambda_loss: 35793884.0000 - val_pred_diff_channels_1_loss: 0.0818 - lr: 5.0000e-04
# Epoch 17/20
# 628/630 [============================>.] - ETA: 0s - loss: 31367034.0000 - padded_obj_loss: 0.2596 - pred_diff_channels_loss: 0.0101 - distribution_lambda_loss: 31367034.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 17: val_loss improved from 35793884.00000 to 35168668.00000, saving model to wts4.1/weights.17.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 31384364.0000 - padded_obj_loss: 0.2596 - pred_diff_channels_loss: 0.0101 - distribution_lambda_loss: 31384364.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 35168668.0000 - val_padded_obj_loss: 0.2562 - val_pred_diff_channels_loss: 0.0104 - val_distribution_lambda_loss: 35168668.0000 - val_pred_diff_channels_1_loss: 0.0818 - lr: 5.0000e-04
# Epoch 18/20
# 630/630 [==============================] - ETA: 0s - loss: 30582582.0000 - padded_obj_loss: 0.2610 - pred_diff_channels_loss: 0.0100 - distribution_lambda_loss: 30582582.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 18: val_loss improved from 35168668.00000 to 33568120.00000, saving model to wts4.1/weights.18.h5
# 630/630 [==============================] - 8s 13ms/step - loss: 30582582.0000 - padded_obj_loss: 0.2610 - pred_diff_channels_loss: 0.0100 - distribution_lambda_loss: 30582582.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 33568120.0000 - val_padded_obj_loss: 0.2585 - val_pred_diff_channels_loss: 0.0105 - val_distribution_lambda_loss: 33568120.0000 - val_pred_diff_channels_1_loss: 0.0825 - lr: 5.0000e-04
# Epoch 19/20
# 626/630 [============================>.] - ETA: 0s - loss: 29900178.0000 - padded_obj_loss: 0.2622 - pred_diff_channels_loss: 0.0100 - distribution_lambda_loss: 29900178.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 19: val_loss improved from 33568120.00000 to 32352588.00000, saving model to wts4.1/weights.19.h5
# 630/630 [==============================] - 8s 12ms/step - loss: 29895348.0000 - padded_obj_loss: 0.2622 - pred_diff_channels_loss: 0.0100 - distribution_lambda_loss: 29895348.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 32352588.0000 - val_padded_obj_loss: 0.2591 - val_pred_diff_channels_loss: 0.0102 - val_distribution_lambda_loss: 32352588.0000 - val_pred_diff_channels_1_loss: 0.0824 - lr: 5.0000e-04
# Epoch 20/20
# 627/630 [============================>.] - ETA: 0s - loss: 28874774.0000 - padded_obj_loss: 0.2635 - pred_diff_channels_loss: 0.0099 - distribution_lambda_loss: 28874774.0000 - pred_diff_channels_1_loss: 0.0837
# Epoch 20: val_loss improved from 32352588.00000 to 32282080.00000, saving model to wts4.1/weights.20.h5
# 630/630 [==============================] - 8s 13ms/step - loss: 28866378.0000 - padded_obj_loss: 0.2635 - pred_diff_channels_loss: 0.0099 - distribution_lambda_loss: 28866378.0000 - pred_diff_channels_1_loss: 0.0837 - val_loss: 32282080.0000 - val_padded_obj_loss: 0.2627 - val_pred_diff_channels_loss: 0.0102 - val_distribution_lambda_loss: 32282080.0000 - val_pred_diff_channels_1_loss: 0.0829 - lr: 5.0000e-04

# %%
# %timeit diffraction_to_obj.predict([X_test])
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 35.8 ms ± 211 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit autoencoder.predict([X_test])

# %%
# plt.plot(np.array(history.history['val_loss']))
# plt.semilogy()

# %%
from ptycho import evaluation
reload(evaluation)

evaluation.plt_metrics(history)

# %%
#plt_metrics()
evaluation.summarize(10, a, b, X_test, Y_I_test, Y_phi_test, probe, 0)
# Out:
# /home/ollie/Documents/scratch/ptycho/ptycho/evaluation.py:49: RuntimeWarning: divide by zero encountered in log
#   plt.subplot(aa, bb, 8)

# %% [markdown]
# ## Evaluate resolution

# %%
np.random.seed(2)
Y_I_2, Y_phi_2, _Y_I_full_2 = simulate_objects(12)

line = np.zeros_like(Y_I_2)
line[:, 31, :, :] = .1
line = f.gf(line, (0, 1, 1, 0))

X_2, Y_I_2, Y_phi_2, _ =\
    illuminate_and_diffract(Y_I_2 + line, Y_phi_2, intensity_scale = intensity_scale)

plt.imshow((Y_I_2 - Y_I_test)[0, :, :, 0])
plt.colorbar()

b2, _, _, _ = autoencoder.predict([X_2])
difference = np.real(b2 - b).mean(axis = 0)

plt.imshow(difference, cmap = 'jet')

lineout_orig = line[0, :, :, 0].sum(axis = 1)
lineout_recon = difference[:, :, 0].sum(axis = 1)

# %%
# %matplotlib inline
#plt.plot(lineout_orig)
plt.plot(lineout_recon)
plt.grid()

# %%
plt.plot(np.abs(f.fftshift(f.fft(lineout_recon)))[32:])
# plt.plot(np.abs(f.fftshift(f.fft(lineout_orig)))[32:])
plt.grid()

# %%
lineout_orig = line[0, :, :, 0].sum(axis = 1)

lineout_recon = difference[:, :, 0].sum(axis = 1)

plt.plot(lineout_orig)
plt.plot(lineout_recon)

# %%
lineout_orig = line[0, :, :, 0].sum(axis = 1)

lineout_recon = difference[:, :, 0].sum(axis = 1)

plt.plot(lineout_orig)
plt.plot(lineout_recon)

# %%
from ptycho import baselines as bl

# %%
big_gridsize = 10
bigoffset = params()['bigoffset']

bordersize = N // 2 - bigoffset // 4
clipsize = (bordersize + ((gridsize - 1) * offset) // 2)

def stitch(b, norm_Y_I_test = 1, nsegments = big_gridsize * 2 - 1):
    img_recon = np.reshape((norm_Y_I_test * np.absolute(b)), (-1, nsegments,
                                                              nsegments, 64, 64, 1))
    img_recon = img_recon[:, :, :, bordersize: -bordersize, bordersize: -bordersize, :]
    tmp = img_recon.transpose(0, 1, 3, 2, 4, 5)
    stitched = tmp.reshape(-1, np.prod(tmp.shape[1:3]), np.prod(tmp.shape[1:3]), 1)
    return stitched

# %%
bordersize = N // 2 - bigoffset // 4
clipsize = (bordersize + ((gridsize - 1) * offset) // 2)

plt.imshow(_Y_I_test_full[0, clipsize: -clipsize, clipsize: -clipsize], interpolation = 'none',
          cmap = 'jet')
vmin = np.min(_Y_I_test_full[0, clipsize: -clipsize, clipsize: -clipsize])
vmax = np.max(_Y_I_test_full[0, clipsize: -clipsize, clipsize: -clipsize])

# %%
plt.rcParams["figure.figsize"] = (10, 10)

stitched = stitch(b, norm_Y_I_test, nsegments=11)

plt.imshow(stitched[0], interpolation = 'none', vmin = vmin, vmax = vmax, cmap = 'jet')

# %%
baseline_model = bl.train((X_train[:, :, :, :1]), Y_I_train[:, :, :, :1], Y_phi_train[:, :, :, :1])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 128)    147584      ['max_pooling2d_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 128)    147584      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 128)    147584      ['conv2d_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    147584      ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 128)  0           ['conv2d_7[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 128)  0          ['conv2d_14[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 64)   73792       ['up_sampling2d[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 64)   73792       ['up_sampling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   36928       ['conv2d_8[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_15[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)  0           ['conv2d_9[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 64)  0           ['conv2d_16[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 32)   18464       ['up_sampling2d_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 32)   18464       ['up_sampling2d_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 32)   9248        ['conv2d_10[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 32)   9248        ['conv2d_17[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)  0           ['conv2d_11[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 32)  0           ['conv2d_18[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 1)    289         ['up_sampling2d_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 1)    289         ['up_sampling2d_5[0][0]']
#
# ==================================================================================================
# Total params: 1,154,210
# Trainable params: 1,154,210
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/60
# 315/315 [==============================] - 5s 14ms/step - loss: 0.5619 - conv2d_12_loss: 0.0207 - conv2d_19_loss: 0.5412 - val_loss: 0.5005 - val_conv2d_12_loss: 0.0086 - val_conv2d_19_loss: 0.4919 - lr: 0.0010
# Epoch 2/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.4427 - conv2d_12_loss: 0.0092 - conv2d_19_loss: 0.4335 - val_loss: 0.4228 - val_conv2d_12_loss: 0.0083 - val_conv2d_19_loss: 0.4145 - lr: 0.0010
# Epoch 3/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.3943 - conv2d_12_loss: 0.0089 - conv2d_19_loss: 0.3854 - val_loss: 0.3719 - val_conv2d_12_loss: 0.0081 - val_conv2d_19_loss: 0.3638 - lr: 0.0010
# Epoch 4/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.3671 - conv2d_12_loss: 0.0081 - conv2d_19_loss: 0.3590 - val_loss: 0.3556 - val_conv2d_12_loss: 0.0090 - val_conv2d_19_loss: 0.3466 - lr: 0.0010
# Epoch 5/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.3455 - conv2d_12_loss: 0.0078 - conv2d_19_loss: 0.3378 - val_loss: 0.3329 - val_conv2d_12_loss: 0.0074 - val_conv2d_19_loss: 0.3255 - lr: 0.0010
# Epoch 6/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.3248 - conv2d_12_loss: 0.0076 - conv2d_19_loss: 0.3171 - val_loss: 0.3162 - val_conv2d_12_loss: 0.0086 - val_conv2d_19_loss: 0.3076 - lr: 0.0010
# Epoch 7/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.3056 - conv2d_12_loss: 0.0075 - conv2d_19_loss: 0.2981 - val_loss: 0.3002 - val_conv2d_12_loss: 0.0075 - val_conv2d_19_loss: 0.2927 - lr: 0.0010
# Epoch 8/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2854 - conv2d_12_loss: 0.0074 - conv2d_19_loss: 0.2780 - val_loss: 0.2815 - val_conv2d_12_loss: 0.0070 - val_conv2d_19_loss: 0.2745 - lr: 0.0010
# Epoch 9/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2672 - conv2d_12_loss: 0.0071 - conv2d_19_loss: 0.2600 - val_loss: 0.2857 - val_conv2d_12_loss: 0.0071 - val_conv2d_19_loss: 0.2785 - lr: 0.0010
# Epoch 10/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2521 - conv2d_12_loss: 0.0068 - conv2d_19_loss: 0.2452 - val_loss: 0.2576 - val_conv2d_12_loss: 0.0067 - val_conv2d_19_loss: 0.2509 - lr: 0.0010
# Epoch 11/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2342 - conv2d_12_loss: 0.0064 - conv2d_19_loss: 0.2278 - val_loss: 0.2364 - val_conv2d_12_loss: 0.0061 - val_conv2d_19_loss: 0.2303 - lr: 0.0010
# Epoch 12/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2221 - conv2d_12_loss: 0.0060 - conv2d_19_loss: 0.2161 - val_loss: 0.2276 - val_conv2d_12_loss: 0.0058 - val_conv2d_19_loss: 0.2218 - lr: 0.0010
# Epoch 13/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2093 - conv2d_12_loss: 0.0056 - conv2d_19_loss: 0.2037 - val_loss: 0.2099 - val_conv2d_12_loss: 0.0057 - val_conv2d_19_loss: 0.2042 - lr: 0.0010
# Epoch 14/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.2011 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1956 - val_loss: 0.2012 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1959 - lr: 0.0010
# Epoch 15/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1902 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1850 - val_loss: 0.1939 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1887 - lr: 0.0010
# Epoch 16/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1826 - conv2d_12_loss: 0.0051 - conv2d_19_loss: 0.1775 - val_loss: 0.1933 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1882 - lr: 0.0010
# Epoch 17/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1753 - conv2d_12_loss: 0.0049 - conv2d_19_loss: 0.1704 - val_loss: 0.1863 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1810 - lr: 0.0010
# Epoch 18/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1701 - conv2d_12_loss: 0.0048 - conv2d_19_loss: 0.1653 - val_loss: 0.1785 - val_conv2d_12_loss: 0.0050 - val_conv2d_19_loss: 0.1735 - lr: 0.0010
# Epoch 19/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1628 - conv2d_12_loss: 0.0047 - conv2d_19_loss: 0.1581 - val_loss: 0.1743 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1692 - lr: 0.0010
# Epoch 20/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1583 - conv2d_12_loss: 0.0046 - conv2d_19_loss: 0.1537 - val_loss: 0.1707 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1659 - lr: 0.0010
# Epoch 21/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1515 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1471 - val_loss: 0.1614 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1569 - lr: 0.0010
# Epoch 22/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1485 - conv2d_12_loss: 0.0045 - conv2d_19_loss: 0.1440 - val_loss: 0.1735 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1687 - lr: 0.0010
# Epoch 23/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1457 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1413 - val_loss: 0.1578 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1531 - lr: 0.0010
# Epoch 24/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1397 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1355 - val_loss: 0.1518 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1473 - lr: 0.0010
# Epoch 25/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1363 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1321 - val_loss: 0.1545 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1499 - lr: 0.0010
# Epoch 26/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1331 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.1290 - val_loss: 0.1510 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1465 - lr: 0.0010
# Epoch 27/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1304 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.1263 - val_loss: 0.1492 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1444 - lr: 0.0010
# Epoch 28/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1283 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.1243 - val_loss: 0.1480 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1435 - lr: 0.0010
# Epoch 29/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1249 - conv2d_12_loss: 0.0040 - conv2d_19_loss: 0.1209 - val_loss: 0.1391 - val_conv2d_12_loss: 0.0044 - val_conv2d_19_loss: 0.1348 - lr: 0.0010
# Epoch 30/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1223 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.1184 - val_loss: 0.1401 - val_conv2d_12_loss: 0.0042 - val_conv2d_19_loss: 0.1359 - lr: 0.0010
# Epoch 31/60
# 311/315 [============================>.] - ETA: 0s - loss: 0.1197 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.1158
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1197 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.1158 - val_loss: 0.1415 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1370 - lr: 0.0010
# Epoch 32/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.1026 - conv2d_12_loss: 0.0033 - conv2d_19_loss: 0.0992 - val_loss: 0.1211 - val_conv2d_12_loss: 0.0037 - val_conv2d_19_loss: 0.1174 - lr: 5.0000e-04
# Epoch 33/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0963 - conv2d_12_loss: 0.0032 - conv2d_19_loss: 0.0931 - val_loss: 0.1187 - val_conv2d_12_loss: 0.0037 - val_conv2d_19_loss: 0.1150 - lr: 5.0000e-04
# Epoch 34/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0943 - conv2d_12_loss: 0.0031 - conv2d_19_loss: 0.0912 - val_loss: 0.1169 - val_conv2d_12_loss: 0.0036 - val_conv2d_19_loss: 0.1132 - lr: 5.0000e-04
# Epoch 35/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0926 - conv2d_12_loss: 0.0031 - conv2d_19_loss: 0.0894 - val_loss: 0.1173 - val_conv2d_12_loss: 0.0037 - val_conv2d_19_loss: 0.1136 - lr: 5.0000e-04
# Epoch 36/60
# 311/315 [============================>.] - ETA: 0s - loss: 0.0917 - conv2d_12_loss: 0.0031 - conv2d_19_loss: 0.0886
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0917 - conv2d_12_loss: 0.0031 - conv2d_19_loss: 0.0887 - val_loss: 0.1170 - val_conv2d_12_loss: 0.0036 - val_conv2d_19_loss: 0.1134 - lr: 5.0000e-04
# Epoch 37/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0838 - conv2d_12_loss: 0.0028 - conv2d_19_loss: 0.0810 - val_loss: 0.1087 - val_conv2d_12_loss: 0.0034 - val_conv2d_19_loss: 0.1054 - lr: 2.5000e-04
# Epoch 38/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0810 - conv2d_12_loss: 0.0028 - conv2d_19_loss: 0.0783 - val_loss: 0.1088 - val_conv2d_12_loss: 0.0034 - val_conv2d_19_loss: 0.1054 - lr: 2.5000e-04
# Epoch 39/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0797 - conv2d_12_loss: 0.0027 - conv2d_19_loss: 0.0770 - val_loss: 0.1075 - val_conv2d_12_loss: 0.0034 - val_conv2d_19_loss: 0.1041 - lr: 2.5000e-04
# Epoch 40/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0791 - conv2d_12_loss: 0.0027 - conv2d_19_loss: 0.0764 - val_loss: 0.1086 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1053 - lr: 2.5000e-04
# Epoch 41/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0781 - conv2d_12_loss: 0.0027 - conv2d_19_loss: 0.0755 - val_loss: 0.1062 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1029 - lr: 2.5000e-04
# Epoch 42/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0770 - conv2d_12_loss: 0.0027 - conv2d_19_loss: 0.0743 - val_loss: 0.1078 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1045 - lr: 2.5000e-04
# Epoch 43/60
# 311/315 [============================>.] - ETA: 0s - loss: 0.0764 - conv2d_12_loss: 0.0026 - conv2d_19_loss: 0.0738
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0764 - conv2d_12_loss: 0.0026 - conv2d_19_loss: 0.0738 - val_loss: 0.1068 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1035 - lr: 2.5000e-04
# Epoch 44/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0728 - conv2d_12_loss: 0.0025 - conv2d_19_loss: 0.0703 - val_loss: 0.1043 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1011 - lr: 1.2500e-04
# Epoch 45/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0716 - conv2d_12_loss: 0.0025 - conv2d_19_loss: 0.0691 - val_loss: 0.1041 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1008 - lr: 1.2500e-04
# Epoch 46/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0710 - conv2d_12_loss: 0.0025 - conv2d_19_loss: 0.0686 - val_loss: 0.1041 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1008 - lr: 1.2500e-04
# Epoch 47/60
# 311/315 [============================>.] - ETA: 0s - loss: 0.0705 - conv2d_12_loss: 0.0025 - conv2d_19_loss: 0.0680
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001.
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0705 - conv2d_12_loss: 0.0025 - conv2d_19_loss: 0.0680 - val_loss: 0.1041 - val_conv2d_12_loss: 0.0033 - val_conv2d_19_loss: 0.1008 - lr: 1.2500e-04
# Epoch 48/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0696 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0672 - val_loss: 0.1032 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.1000 - lr: 1.0000e-04
# Epoch 49/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0691 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0667 - val_loss: 0.1033 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.1001 - lr: 1.0000e-04
# Epoch 50/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0687 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0663 - val_loss: 0.1032 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.1000 - lr: 1.0000e-04
# Epoch 51/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0684 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0660 - val_loss: 0.1031 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0999 - lr: 1.0000e-04
# Epoch 52/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0680 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0656 - val_loss: 0.1026 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0994 - lr: 1.0000e-04
# Epoch 53/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0677 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0653 - val_loss: 0.1026 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0994 - lr: 1.0000e-04
# Epoch 54/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0673 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0649 - val_loss: 0.1024 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0992 - lr: 1.0000e-04
# Epoch 55/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0671 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0648 - val_loss: 0.1025 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0993 - lr: 1.0000e-04
# Epoch 56/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0668 - conv2d_12_loss: 0.0024 - conv2d_19_loss: 0.0644 - val_loss: 0.1020 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0988 - lr: 1.0000e-04
# Epoch 57/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0664 - conv2d_12_loss: 0.0023 - conv2d_19_loss: 0.0641 - val_loss: 0.1019 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0987 - lr: 1.0000e-04
# Epoch 58/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0661 - conv2d_12_loss: 0.0023 - conv2d_19_loss: 0.0638 - val_loss: 0.1021 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0989 - lr: 1.0000e-04
# Epoch 59/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0658 - conv2d_12_loss: 0.0023 - conv2d_19_loss: 0.0634 - val_loss: 0.1019 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0987 - lr: 1.0000e-04
# Epoch 60/60
# 315/315 [==============================] - 4s 12ms/step - loss: 0.0656 - conv2d_12_loss: 0.0023 - conv2d_19_loss: 0.0633 - val_loss: 0.1019 - val_conv2d_12_loss: 0.0032 - val_conv2d_19_loss: 0.0987 - lr: 1.0000e-04

# %%
baseline_pred_I, baseline_pred_phi = baseline_model.predict([X_test[:, :, :, 0]])
baseline_stitched = stitch(baseline_pred_I, norm_Y_I_test, nsegments=11)

plt.imshow(baseline_stitched[0], cmap = 'jet', vmin = vmin, vmax = vmax)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
gt = _Y_I_test_full[:, clipsize: -clipsize, clipsize: -clipsize]
tf.keras.losses.MeanAbsoluteError()(gt, stitched)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0040464187>

# %%
tf.keras.losses.MeanSquaredError()(gt, stitched)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.37226e-05>

# %%
tf.keras.losses.MeanAbsoluteError()(gt, baseline_stitched)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0077292537>

# %%
tf.keras.losses.MeanSquaredError()(gt, baseline_stitched)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00013008271>

# %%
baseline_model.evaluate([X_test[:, :, :, 0]])
# Out:
# 4/4 [==============================] - 0s 806us/step - loss: 0.0000e+00 - conv2d_12_loss: 0.0000e+00 - conv2d_19_loss: 0.0000e+00
# [0.0, 0.0, 0.0]

# %%
i = 0
# consistency check: should be close to equal
np.sum(tf.math.abs(a[i])**2), np.sum(tf.math.abs(X_test[i])**2),\
np.sum(tf.math.abs(a)**2), np.sum(tf.math.abs(X_test)**2)
# Out:
# (1296.268, 1232.1055, 163924.03, 164390.33)

# %%
plt.imshow(np.log(.2 + np.abs((a[i, :, :, 0] - X_test[i, :, :, 0]) / (X_test[i, :, :, 0] + 1e-9))), cmap ='jet')
plt.colorbar()

# %%
# off = 1
# vmin = 0
# vmax = 1

# aa, bb = 1, 2
# plt.subplot(aa, bb, 1)
# plt.title('Ground truth amp.')
# cropshow((Y_I_test[i, :, :, 0]), cmap = 'jet', vmin = vmin, vmax = vmax)

# plt.subplot(aa, bb, 2)
# plt.title('Reconstructed amp.')
# cropshow((np.absolute(b))[i, :, :, 0], cmap = 'jet', vmin = vmin, vmax = vmax)

# %%
# !ln ../xrd_clustering/notebooks/visualization.py
from ptycho import visualization as vis
reload(vis)
# Out:
# <module 'ptycho.visualization' from '/home/ollie/Documents/scratch/ptycho/ptycho/visualization.py'>

# %%
off = 5

vmin = np.min(Y_I_test[:, 16:-16, 16:-16][i:i + off])
vmax = np.max(Y_I_test[:, 16:-16, 16:-16][i:i + off])

print('diffraction reconstruction')
vis.display_imgs(np.log(np.absolute(a[:, :, :, 0]))[i:i + off])

print('diffraction ground truth')
vis.display_imgs(np.log(np.absolute(X_test[:, :, :, 0]))[i:i + off])

print('object reconstruction (amp)')
vis.display_imgs(np.absolute(b[:, 16:-16, 16:-16, 0])[i:i + off], vmin = vmin, vmax = vmax)
# print('object reconstruction (phase)')
# vis.display_imgs(np.angle(b[:, 16:-16, 16:-16, 0])[i:i + 10])#, vmin = vmin, vmax = vmax)
print('object ground truth')
vis.display_imgs(Y_I_test[:, 16:-16, 16:-16, 0][i:i + off], vmin = vmin, vmax = vmax)
# Out:
# diffraction reconstruction
# diffraction ground truth
# /tmp/ipykernel_671127/1178352548.py:10: RuntimeWarning: divide by zero encountered in log
#   vis.display_imgs(np.log(np.absolute(X_test[:, :, :, 0]))[i:i + off])
# object reconstruction (amp)
# object ground truth

# %% [markdown]
# ## save model

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'pred_amplitude_loss', 'padded_obj_loss', 'pred_amplitude_1_loss', 'val_loss', 'val_pred_amplitude_loss', 'val_padded_obj_loss', 'val_pred_amplitude_1_loss', 'lr'])

# %%
np.save(path+'str_history', history.history)

# %%
# model.load_weights(checkpoint_filepath)

# %%
# val_losses=hist.history['val_loss']
# min_epoch=np.argmin(val_losses)+1
# print (min_epoch)
# np.save(path+'%s/min_epoch' %(wt_path), min_epoch)
autoencoder.save('{}.h5'.format(wt_path))
